# %% [markdown]
# ## Imports, Configurations, and Paths

# %%
# Data Manipulation
import numpy as np
import pandas as pd
from pandas.io.formats.style import Styler

# Stats and Utilities
import os
import itertools
import warnings
from IPython.display import display
from typing import Dict, List, Tuple

# Visualization
import matplotlib.pyplot as plt
import seaborn as sns

# Preprocessing and Clustering
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.manifold import TSNE
from sklearn.metrics import silhouette_score, davies_bouldin_score, calinski_harabasz_score
from sklearn.cluster import KMeans, Birch
from sklearn.mixture import GaussianMixture
import hdbscan

# %%
# CONFIGURATION
RANDOM_STATE = 42
DATA_PATH = "./Data/telecom_preprocessed.csv"
ORIGINAL_PATH = "./Data/Telecom/Telecom_customer_dataset.csv"
TOP_K_FEATURES = 10
pd.set_option("display.max_columns", 50)

# %% [markdown]
# ## HELPER FUNCTIONS

# %% [markdown]
# ### Data Loading and Scaling

# %%
# Load the pre‑processed dataset
def load_dataset(path: str = DATA_PATH) -> pd.DataFrame:
    return pd.read_csv(path)

# %%
# Return a standard‑scaled copy of the data and the fitted scaler
def scale_features(df: pd.DataFrame) -> Tuple[pd.DataFrame, StandardScaler]:
    scaler = StandardScaler()
    df_scaled = pd.DataFrame(
        scaler.fit_transform(df.values),
        columns=df.columns,
        index=df.index,
    )
    return df_scaled, scaler

# %%
# Convert scaled data back to original units using the original dataset
def inverse_scale(
    df_scaled: pd.DataFrame,
    scaler: StandardScaler,
    original_path: str = ORIGINAL_PATH,
) -> pd.DataFrame:
    df_original = pd.read_csv(original_path)
    common_cols = [c for c in df_scaled.columns if c in df_original.columns]
    df_inv = pd.DataFrame(
        scaler.inverse_transform(df_scaled[common_cols]),
        columns=common_cols,
        index=df_scaled.index,
    )
    return df_inv

# %% [markdown]
# ### Cluster Metrics

# %%
# Compute clustering quality indices (Silhouette, Davies–Bouldin, Calinski–Harabasz)
def clustering_metrics(X: np.ndarray, labels: np.ndarray) -> Dict[str, float]:
    unique = np.setdiff1d(np.unique(labels), [-1])  # ignore noise label -1
    if len(unique) < 2:
        return {"silhouette": np.nan, "davies": np.nan, "calinski": np.nan}

    return {
        "silhouette": silhouette_score(X, labels),
        "davies": davies_bouldin_score(X, labels),
        "calinski": calinski_harabasz_score(X, labels),
    }

# %% [markdown]
# ### Tabular Cluster Explanations

# %%
# Summarize each cluster with top-k features by within-cluster variance
def cluster_summary(
    df: pd.DataFrame,
    labels: np.ndarray,
    top_k_features: int = TOP_K_FEATURES,
) -> pd.DataFrame:
    labelled = df.copy()
    labelled["cluster"] = labels

    variances = (
        labelled.groupby("cluster")
        .var(numeric_only=True)
        .median()
        .sort_values(ascending=False)
    )
    top_features = variances.head(top_k_features).index.tolist()

    summary = (
        labelled.groupby("cluster")[top_features]
        .agg(["count", "mean", "std", "min", "max"])
        .swaplevel(axis=1)
        .sort_index(axis=1, level=0)
    )
    return summary

# %%
# List top-variable features per cluster by variance
def top_variable(
    df: pd.DataFrame,
    labels: np.ndarray,
    n_features: int = TOP_K_FEATURES,
    cluster_col: str = "cluster",
) -> Dict[int, List[str]]:
    labelled = df.copy()
    labelled[cluster_col] = labels

    num_cols = labelled.select_dtypes(include="number").columns.difference([cluster_col])
    result: Dict[int, List[str]] = {}
    for cid, grp in labelled.groupby(cluster_col):
        result[cid] = (
            grp[num_cols]
            .var()
            .sort_values(ascending=False)
            .head(n_features)
            .index.tolist()
        )
    return result

# %%
# Display a styled summary table in notebooks
def show_summary(
    summary: pd.DataFrame,
    caption: str = "Cluster summary (top features)",
) -> pd.io.formats.style.Styler:
    sty = (
        summary.style
        .set_caption(caption)
        .background_gradient(axis=None, cmap="Blues", vmin=summary.min().min())
        .format(precision=2)
    )
    display(sty)
    return sty

# %% [markdown]
# ### Visualization Helpers

# %%
# Plot PCA two‑dimensional scatter of clusters
def plot_pca(X: pd.DataFrame, labels: np.ndarray, n_components: int = 2) -> None:
    pca = PCA(n_components=n_components, random_state=RANDOM_STATE)
    coords = pca.fit_transform(X)
    plt.figure(figsize=(8, 6))
    sns.scatterplot(x=coords[:, 0], y=coords[:, 1], hue=labels, palette="tab10", s=60, edgecolor="k")
    plt.title("PCA Projection of Clusters")
    plt.xlabel("PC 1")
    plt.ylabel("PC 2")
    plt.tight_layout()
    plt.show()

# %%
# Plot t‑SNE two‑dimensional scatter of clusters
def plot_tsne(X: pd.DataFrame, labels: np.ndarray, perplexity: int = 30, lr: int = 200) -> None:
    tsne = TSNE(n_components=2, perplexity=perplexity, learning_rate=lr, random_state=RANDOM_STATE, init="pca")
    coords = tsne.fit_transform(X)
    plt.figure(figsize=(8, 6))
    sns.scatterplot(x=coords[:, 0], y=coords[:, 1], hue=labels, palette="tab10", s=60, edgecolor="k")
    plt.title("t‑SNE Projection of Clusters")
    plt.xlabel("t‑SNE 1")
    plt.ylabel("t‑SNE 2")
    plt.tight_layout()
    plt.show()

# %%
# Plot feature distribution heatmap for selected top features
def plot_cluster_heatmap(df: pd.DataFrame, labels: np.ndarray, top_features: list) -> None:
    df = df[top_features].copy()
    df["cluster"] = labels
    heat_data = df.groupby("cluster").median()
    plt.figure(figsize=(10, 6))
    sns.heatmap(heat_data, annot=True, fmt=".2f", cmap="viridis")
    plt.title("Median Feature Values per Cluster")
    plt.tight_layout()
    plt.show()

# %%
# Plot boxplots of chosen features split by cluster
def plot_feature_boxplots(df: pd.DataFrame, labels: np.ndarray, features: list) -> None:
    df = df.copy()
    df["cluster"] = labels
    for feature in features:
        plt.figure(figsize=(6, 4))
        sns.boxplot(x="cluster", y=feature, data=df, palette="tab10")
        plt.title(f"{feature} Distribution by Cluster")
        plt.tight_layout()
        plt.show()

# %%
# Plot parallel coordinates chart of cluster centres
def plot_parallel_coordinates(df: pd.DataFrame, labels: np.ndarray, top_features: list, sample_size: int = 1000) -> None:
    sample_df = df[top_features].copy()
    sample_df["cluster"] = labels
    if len(sample_df) > sample_size:
        sample_df = sample_df.sample(sample_size, random_state=RANDOM_STATE)
    plt.figure(figsize=(10, 6))
    pd.plotting.parallel_coordinates(sample_df, "cluster", colormap="tab10", alpha=0.4)
    plt.title("Parallel Coordinates of Top Features by Cluster")
    plt.tight_layout()
    plt.show()

# %%
# Plot radar chart of cluster centroids
def plot_radar_chart(df: pd.DataFrame, labels: np.ndarray, top_features: list) -> None:
    centroid_df = (
        df[top_features]
        .assign(cluster=labels)
        .groupby("cluster")
        .median()
    )
    categories = list(centroid_df.columns)
    n_clusters = centroid_df.shape[0]
    angles = np.linspace(0, 2 * np.pi, len(categories), endpoint=False).tolist()
    angles += angles[:1]
    plt.figure(figsize=(8, 8))
    for idx in range(n_clusters):
        values = centroid_df.iloc[idx].tolist()
        values += values[:1]
        plt.polar(angles, values, marker="o", label=f"Cluster {idx}")
    plt.xticks(angles[:-1], categories, fontsize=8)
    plt.title("Cluster Centroid Radar Chart", y=1.08)
    plt.legend(loc="upper right", bbox_to_anchor=(1.3, 1.1))
    plt.tight_layout()
    plt.show()

# %% [markdown]
# ### Algorithm Helpers

# %% [markdown]
# #### K-Means

# %%
# Run K‑Means clustering and generate metrics, tables, and visualisations
def run_kmeans(X_scaled: np.ndarray, df_original: pd.DataFrame, n_clusters: int = 3, top_n: int = 10, random_state: int = RANDOM_STATE, use_original: bool = False):
    km = KMeans(n_clusters=n_clusters, random_state=random_state)
    labels = km.fit_predict(X_scaled)
    metrics = compute_cluster_metrics(X_scaled, labels)
    df_for_stats = df_original if use_original else pd.DataFrame(X_scaled, columns=df_original.columns)
    summary = cluster_summary(df_for_stats, labels)
    top_vars = top_variable(df_for_stats, labels, n_features=top_n)
    show_styled_df(summary, caption="K‑Means per‑cluster summary")
    plot_pca(X_scaled, labels, f"K‑Means (k={n_clusters}) – PCA 2‑D")
    plot_cluster_heatmap(df_for_stats, labels, top_vars, "K‑Means median feature heatmap")
    plot_parallel_coordinates(df_original, labels, top_vars, "K‑Means parallel coordinates", use_original)
    return {"labels": labels, "metrics": metrics, "summary": summary, "top_vars": top_vars}

# %% [markdown]
# #### GMM

# %%
# Run GMM clustering and generate metrics, tables, and visualisations
def run_gmm(X_scaled: np.ndarray, df_original: pd.DataFrame, n_components: int = 6, top_n: int = 10, random_state: int = RANDOM_STATE, use_original: bool = False):
    gmm = GaussianMixture(n_components=n_components, random_state=random_state)
    labels = gmm.fit_predict(X_scaled)
    metrics = compute_cluster_metrics(X_scaled, labels)
    df_for_stats = df_original if use_original else pd.DataFrame(X_scaled, columns=df_original.columns)
    summary = cluster_summary(df_for_stats, labels)
    top_vars = top_variable(df_for_stats, labels, n_features=top_n)
    show_styled_df(summary, caption="GMM per‑cluster summary")
    plot_pca(X_scaled, labels, f"GMM (k={n_components}) – PCA 2‑D")
    plot_cluster_heatmap(df_for_stats, labels, top_vars, "GMM median feature heatmap")
    plot_parallel_coordinates(df_original, labels, top_vars, "GMM parallel coordinates", use_original)
    return {"labels": labels, "metrics": metrics, "summary": summary, "top_vars": top_vars}

# %% [markdown]
# #### BIRCH

# %%
# Run Birch
def run_birch(X_scaled: np.ndarray, df_original: pd.DataFrame, threshold: float = 0.5, k_final: int = 4, top_n: int = 10, random_state: int = RANDOM_STATE, use_original: bool = False):
    birch = Birch(n_clusters=None, threshold=threshold)
    labels_sub = birch.fit_predict(X_scaled)
    centres    = birch.subcluster_centers_
    km_final   = KMeans(n_clusters=k_final, random_state=random_state)
    labels_final = km_final.fit_predict(centres)
    labels = np.array([labels_final[idx] for idx in labels_sub])
    metrics = compute_cluster_metrics(X_scaled, labels)
    df_for_stats = df_original if use_original else pd.DataFrame(X_scaled, columns=df_original.columns)
    summary = cluster_summary(df_for_stats, labels)
    top_vars = top_variable(df_for_stats, labels, n_features=top_n)
    show_styled_df(summary, caption="Birch per‑cluster summary")
    plot_pca(X_scaled, labels, f"Birch (k={k_final}) – PCA 2‑D")
    plot_cluster_heatmap(df_for_stats, labels, top_vars, "Birch median feature heatmap")
    plot_parallel_coordinates(df_original, labels, top_vars, "Birch parallel coordinates", use_original)
    return {"labels": labels, "metrics": metrics, "summary": summary, "top_vars": top_vars}

# %% [markdown]
# #### HDBSCAN

# %%
# Run density‑based HDBSCAN clustering and generate outputs (set use_original=True for original dataset)
def run_hdbscan(X_scaled: np.ndarray, df_original: pd.DataFrame, min_cluster_size: int = 50, min_samples: int = 10, top_n: int = 10, use_original: bool = False):
    hdb = hdbscan.HDBSCAN(
        min_cluster_size=min_cluster_size,
        min_samples=min_samples,
        metric="euclidean",
        core_dist_n_jobs=-1,
        prediction_data=False,
    )
    labels = hdb.fit_predict(X_scaled)
    metrics = compute_cluster_metrics(X_scaled, labels)
    df_for_stats = df_original if use_original else pd.DataFrame(X_scaled, columns=df_original.columns)
    summary = cluster_summary(df_for_stats, labels)
    top_vars = top_variable(df_for_stats, labels, n_features=top_n)
    show_styled_df(summary, caption="HDBSCAN per‑cluster summary")
    plot_pca(X_scaled, labels, "HDBSCAN – PCA 2‑D")
    plot_cluster_heatmap(df_for_stats, labels, top_vars, "HDBSCAN median feature heatmap")
    plot_parallel_coordinates(df_original, labels, top_vars, "HDBSCAN parallel coordinates", use_original)
    return {"labels": labels, "metrics": metrics, "summary": summary, "top_vars": top_vars}

# %% [markdown]
# ## DATA LOADING

# %%
df = load_dataset(DATA_PATH)

# %%
pca_final = PCA(n_components=30, random_state=42)
X = pca_final.fit_transform(df)

print(f"PCA reduced shape: {X.shape}")
# Out:
# PCA reduced shape: (100000, 30)

# %%
cols_to_drop = ["Customer_ID", "churn"]

df_original = load_dataset(ORIGINAL_PATH)
df_original = df_original.drop(columns=cols_to_drop, errors="ignore")

# %% [markdown]
# ## K-MEANS

# %%
n_clusters = 3
kmeans = KMeans(n_clusters=n_clusters, random_state=RANDOM_STATE)
kmeans_labels = kmeans.fit_predict(X)

# %%
kmeans_metrics = clustering_metrics(X, kmeans_labels)
kmeans_metrics
# Out:
# {'silhouette': 0.405979182588089,
#  'davies': 1.171774309377924,
#  'calinski': 32291.534100064757}

# %%
df_kmeans_labeled = df_original.copy()
df_kmeans_labeled["cluster"] = kmeans_labels

# %%
kmeans_summary = cluster_summary(df_kmeans_labeled, kmeans_labels)
show_summary(kmeans_summary, caption="KMeans Cluster Summary")
# Out:
# <style type="text/css">
# #T_a8746_row0_col0, #T_a8746_row0_col1, #T_a8746_row0_col2, #T_a8746_row0_col3, #T_a8746_row0_col4, #T_a8746_row0_col5, #T_a8746_row0_col6, #T_a8746_row0_col7, #T_a8746_row0_col8, #T_a8746_row0_col9 {
#   background-color: #ecf4fb;
#   color: #000000;
# }
# #T_a8746_row0_col10 {
#   background-color: #084990;
#   color: #f1f1f1;
# }
# #T_a8746_row0_col11 {
#   background-color: #8dc1dd;
#   color: #000000;
# }
# #T_a8746_row0_col12, #T_a8746_row0_col19 {
#   background-color: #e0ecf8;
#   color: #000000;
# }
# #T_a8746_row0_col13, #T_a8746_row2_col13, #T_a8746_row2_col16, #T_a8746_row2_col20, #T_a8746_row2_col28 {
#   background-color: #f1f7fd;
#   color: #000000;
# }
# #T_a8746_row0_col14, #T_a8746_row0_col15, #T_a8746_row1_col40, #T_a8746_row1_col48, #T_a8746_row2_col14 {
#   background-color: #f2f7fd;
#   color: #000000;
# }
# #T_a8746_row0_col16 {
#   background-color: #edf4fc;
#   color: #000000;
# }
# #T_a8746_row0_col17 {
#   background-color: #8cc0dd;
#   color: #000000;
# }
# #T_a8746_row0_col18 {
#   background-color: #08488e;
#   color: #f1f1f1;
# }
# #T_a8746_row0_col20, #T_a8746_row1_col0, #T_a8746_row1_col1, #T_a8746_row1_col2, #T_a8746_row1_col3, #T_a8746_row1_col4, #T_a8746_row1_col5, #T_a8746_row1_col6, #T_a8746_row1_col7, #T_a8746_row1_col8, #T_a8746_row1_col9 {
#   background-color: #eff6fc;
#   color: #000000;
# }
# #T_a8746_row0_col21, #T_a8746_row0_col27, #T_a8746_row0_col41, #T_a8746_row1_col13, #T_a8746_row2_col41, #T_a8746_row2_col47 {
#   background-color: #f4f9fe;
#   color: #000000;
# }
# #T_a8746_row0_col22, #T_a8746_row0_col29, #T_a8746_row0_col42, #T_a8746_row0_col49, #T_a8746_row1_col21, #T_a8746_row1_col27, #T_a8746_row2_col22, #T_a8746_row2_col29 {
#   background-color: #f6faff;
#   color: #000000;
# }
# #T_a8746_row0_col23, #T_a8746_row0_col24, #T_a8746_row0_col25, #T_a8746_row0_col26, #T_a8746_row0_col30, #T_a8746_row0_col31, #T_a8746_row0_col32, #T_a8746_row0_col33, #T_a8746_row0_col34, #T_a8746_row0_col35, #T_a8746_row0_col36, #T_a8746_row0_col37, #T_a8746_row0_col38, #T_a8746_row0_col39, #T_a8746_row0_col43, #T_a8746_row0_col44, #T_a8746_row0_col45, #T_a8746_row0_col46, #T_a8746_row1_col22, #T_a8746_row1_col23, #T_a8746_row1_col24, #T_a8746_row1_col25, #T_a8746_row1_col26, #T_a8746_row1_col29, #T_a8746_row1_col30, #T_a8746_row1_col31, #T_a8746_row1_col32, #T_a8746_row1_col33, #T_a8746_row1_col34, #T_a8746_row1_col35, #T_a8746_row1_col36, #T_a8746_row1_col37, #T_a8746_row1_col38, #T_a8746_row1_col39, #T_a8746_row1_col42, #T_a8746_row1_col43, #T_a8746_row1_col44, #T_a8746_row1_col45, #T_a8746_row1_col46, #T_a8746_row1_col49, #T_a8746_row2_col23, #T_a8746_row2_col24, #T_a8746_row2_col25, #T_a8746_row2_col26, #T_a8746_row2_col30, #T_a8746_row2_col31, #T_a8746_row2_col32, #T_a8746_row2_col33, #T_a8746_row2_col34, #T_a8746_row2_col35, #T_a8746_row2_col36, #T_a8746_row2_col37, #T_a8746_row2_col38, #T_a8746_row2_col39, #T_a8746_row2_col42, #T_a8746_row2_col43, #T_a8746_row2_col44, #T_a8746_row2_col45, #T_a8746_row2_col46, #T_a8746_row2_col49 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_a8746_row0_col28, #T_a8746_row0_col40, #T_a8746_row0_col48, #T_a8746_row1_col12, #T_a8746_row1_col19 {
#   background-color: #eef5fc;
#   color: #000000;
# }
# #T_a8746_row0_col47, #T_a8746_row1_col20, #T_a8746_row1_col28 {
#   background-color: #f3f8fe;
#   color: #000000;
# }
# #T_a8746_row1_col10 {
#   background-color: #519ccc;
#   color: #f1f1f1;
# }
# #T_a8746_row1_col11 {
#   background-color: #b4d3e9;
#   color: #000000;
# }
# #T_a8746_row1_col14, #T_a8746_row1_col15, #T_a8746_row1_col16, #T_a8746_row1_col41, #T_a8746_row1_col47, #T_a8746_row2_col21, #T_a8746_row2_col27 {
#   background-color: #f5f9fe;
#   color: #000000;
# }
# #T_a8746_row1_col17 {
#   background-color: #b3d3e8;
#   color: #000000;
# }
# #T_a8746_row1_col18 {
#   background-color: #4f9bcb;
#   color: #f1f1f1;
# }
# #T_a8746_row2_col0, #T_a8746_row2_col1, #T_a8746_row2_col2, #T_a8746_row2_col3, #T_a8746_row2_col5, #T_a8746_row2_col6, #T_a8746_row2_col7, #T_a8746_row2_col8, #T_a8746_row2_col9 {
#   background-color: #aed1e7;
#   color: #000000;
# }
# #T_a8746_row2_col4 {
#   background-color: #b0d2e7;
#   color: #000000;
# }
# #T_a8746_row2_col10, #T_a8746_row2_col18 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_a8746_row2_col11, #T_a8746_row2_col17 {
#   background-color: #8abfdd;
#   color: #000000;
# }
# #T_a8746_row2_col12, #T_a8746_row2_col19 {
#   background-color: #e7f0fa;
#   color: #000000;
# }
# #T_a8746_row2_col15 {
#   background-color: #f2f8fd;
#   color: #000000;
# }
# #T_a8746_row2_col40, #T_a8746_row2_col48 {
#   background-color: #f0f6fd;
#   color: #000000;
# }
# </style>
# <table id="T_a8746">
#   <caption>KMeans Cluster Summary</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a8746_level0_col0" class="col_heading level0 col0" colspan="10">count</th>
#       <th id="T_a8746_level0_col10" class="col_heading level0 col10" colspan="10">max</th>
#       <th id="T_a8746_level0_col20" class="col_heading level0 col20" colspan="10">mean</th>
#       <th id="T_a8746_level0_col30" class="col_heading level0 col30" colspan="10">min</th>
#       <th id="T_a8746_level0_col40" class="col_heading level0 col40" colspan="10">std</th>
#     </tr>
#     <tr>
#       <th class="blank level1" >&nbsp;</th>
#       <th id="T_a8746_level1_col0" class="col_heading level1 col0" >adjmou</th>
#       <th id="T_a8746_level1_col1" class="col_heading level1 col1" >adjqty</th>
#       <th id="T_a8746_level1_col2" class="col_heading level1 col2" >adjrev</th>
#       <th id="T_a8746_level1_col3" class="col_heading level1 col3" >avg3mou</th>
#       <th id="T_a8746_level1_col4" class="col_heading level1 col4" >avg6mou</th>
#       <th id="T_a8746_level1_col5" class="col_heading level1 col5" >avgmou</th>
#       <th id="T_a8746_level1_col6" class="col_heading level1 col6" >mou_Mean</th>
#       <th id="T_a8746_level1_col7" class="col_heading level1 col7" >totcalls</th>
#       <th id="T_a8746_level1_col8" class="col_heading level1 col8" >totmou</th>
#       <th id="T_a8746_level1_col9" class="col_heading level1 col9" >totrev</th>
#       <th id="T_a8746_level1_col10" class="col_heading level1 col10" >adjmou</th>
#       <th id="T_a8746_level1_col11" class="col_heading level1 col11" >adjqty</th>
#       <th id="T_a8746_level1_col12" class="col_heading level1 col12" >adjrev</th>
#       <th id="T_a8746_level1_col13" class="col_heading level1 col13" >avg3mou</th>
#       <th id="T_a8746_level1_col14" class="col_heading level1 col14" >avg6mou</th>
#       <th id="T_a8746_level1_col15" class="col_heading level1 col15" >avgmou</th>
#       <th id="T_a8746_level1_col16" class="col_heading level1 col16" >mou_Mean</th>
#       <th id="T_a8746_level1_col17" class="col_heading level1 col17" >totcalls</th>
#       <th id="T_a8746_level1_col18" class="col_heading level1 col18" >totmou</th>
#       <th id="T_a8746_level1_col19" class="col_heading level1 col19" >totrev</th>
#       <th id="T_a8746_level1_col20" class="col_heading level1 col20" >adjmou</th>
#       <th id="T_a8746_level1_col21" class="col_heading level1 col21" >adjqty</th>
#       <th id="T_a8746_level1_col22" class="col_heading level1 col22" >adjrev</th>
#       <th id="T_a8746_level1_col23" class="col_heading level1 col23" >avg3mou</th>
#       <th id="T_a8746_level1_col24" class="col_heading level1 col24" >avg6mou</th>
#       <th id="T_a8746_level1_col25" class="col_heading level1 col25" >avgmou</th>
#       <th id="T_a8746_level1_col26" class="col_heading level1 col26" >mou_Mean</th>
#       <th id="T_a8746_level1_col27" class="col_heading level1 col27" >totcalls</th>
#       <th id="T_a8746_level1_col28" class="col_heading level1 col28" >totmou</th>
#       <th id="T_a8746_level1_col29" class="col_heading level1 col29" >totrev</th>
#       <th id="T_a8746_level1_col30" class="col_heading level1 col30" >adjmou</th>
#       <th id="T_a8746_level1_col31" class="col_heading level1 col31" >adjqty</th>
#       <th id="T_a8746_level1_col32" class="col_heading level1 col32" >adjrev</th>
#       <th id="T_a8746_level1_col33" class="col_heading level1 col33" >avg3mou</th>
#       <th id="T_a8746_level1_col34" class="col_heading level1 c
# <style type="text/css">
# #T_a8746_row0_col0, #T_a8746_row0_col1, #T_a8746_row0_col2, #T_a8746_row0_col3, #T_a8746_row0_col4, #T_a8746_row0_col5, #T_a8746_row0_col6, #T_a8746_row0_col7, #T_a8746_row0_col8, #T_a8746_row0_col9 {
#   background-color: #ecf4fb;
#   color: #000000;
# }
# #T_a8746_row0_col10 {
#   background-color: #084990;
#   color: #f1f1f1;
# }
# #T_a8746_row0_col11 {
#   background-color: #8dc1dd;
#   color: #000000;
# }
# #T_a8746_row0_col12, #T_a8746_row0_col19 {
#   background-color: #e0ecf8;
#   color: #000000;
# }
# #T_a8746_row0_col13, #T_a8746_row2_col13, #T_a8746_row2_col16, #T_a8746_row2_col20, #T_a8746_row2_col28 {
#   background-color: #f1f7fd;
#   color: #000000;
# }
# #T_a8746_row0_col14, #T_a8746_row0_col15, #T_a8746_row1_col40, #T_a8746_row1_col48, #T_a8746_row2_col14 {
#   background-color: #f2f7fd;
#   color: #000000;
# }
# #T_a8746_row0_col16 {
#   background-color: #edf4fc;
#   color: #000000;
# }
# #T_a8746_row0_col17 {
#   background-color: #8cc0dd;
#   color: #000000;
# }
# #T_a8746_row0_col18 {
#   background-color: #08488e;
#   color: #f1f1f1;
# }
# #T_a8746_row0_col20, #T_a8746_row1_col0, #T_a8746_row1_col1, #T_a8746_row1_col2, #T_a8746_row1_col3, #T_a8746_row1_col4, #T_a8746_row1_col5, #T_a8746_row1_col6, #T_a8746_row1_col7, #T_a8746_row1_col8, #T_a8746_row1_col9 {
#   background-color: #eff6fc;
#   color: #000000;
# }
# #T_a8746_row0_col21, #T_a8746_row0_col27, #T_a8746_row0_col41, #T_a8746_row1_col13, #T_a8746_row2_col41, #T_a8746_row2_col47 {
#   background-color: #f4f9fe;
#   color: #000000;
# }
# #T_a8746_row0_col22, #T_a8746_row0_col29, #T_a8746_row0_col42, #T_a8746_row0_col49, #T_a8746_row1_col21, #T_a8746_row1_col27, #T_a8746_row2_col22, #T_a8746_row2_col29 {
#   background-color: #f6faff;
#   color: #000000;
# }
# #T_a8746_row0_col23, #T_a8746_row0_col24, #T_a8746_row0_col25, #T_a8746_row0_col26, #T_a8746_row0_col30, #T_a8746_row0_col31, #T_a8746_row0_col32, #T_a8746_row0_col33, #T_a8746_row0_col34, #T_a8746_row0_col35, #T_a8746_row0_col36, #T_a8746_row0_col37, #T_a8746_row0_col38, #T_a8746_row0_col39, #T_a8746_row0_col43, #T_a8746_row0_col44, #T_a8746_row0_col45, #T_a8746_row0_col46, #T_a8746_row1_col22, #T_a8746_row1_col23, #T_a8746_row1_col24, #T_a8746_row1_col25, #T_a8746_row1_col26, #T_a8746_row1_col29, #T_a8746_row1_col30, #T_a8746_row1_col31, #T_a8746_row1_col32, #T_a8746_row1_col33, #T_a8746_row1_col34, #T_a8746_row1_col35, #T_a8746_row1_col36, #T_a8746_row1_col37, #T_a8746_row1_col38, #T_a8746_row1_col39, #T_a8746_row1_col42, #T_a8746_row1_col43, #T_a8746_row1_col44, #T_a8746_row1_col45, #T_a8746_row1_col46, #T_a8746_row1_col49, #T_a8746_row2_col23, #T_a8746_row2_col24, #T_a8746_row2_col25, #T_a8746_row2_col26, #T_a8746_row2_col30, #T_a8746_row2_col31, #T_a8746_row2_col32, #T_a8746_row2_col33, #T_a8746_row2_col34, #T_a8746_row2_col35, #T_a8746_row2_col36, #T_a8746_row2_col37, #T_a8746_row2_col38, #T_a8746_row2_col39, #T_a8746_row2_col42, #T_a8746_row2_col43, #T_a8746_row2_col44, #T_a8746_row2_col45, #T_a8746_row2_col46, #T_a8746_row2_col49 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_a8746_row0_col28, #T_a8746_row0_col40, #T_a8746_row0_col48, #T_a8746_row1_col12, #T_a8746_row1_col19 {
#   background-color: #eef5fc;
#   color: #000000;
# }
# #T_a8746_row0_col47, #T_a8746_row1_col20, #T_a8746_row1_col28 {
#   background-color: #f3f8fe;
#   color: #000000;
# }
# #T_a8746_row1_col10 {
#   background-color: #519ccc;
#   color: #f1f1f1;
# }
# #T_a8746_row1_col11 {
#   background-color: #b4d3e9;
#   color: #000000;
# }
# #T_a8746_row1_col14, #T_a8746_row1_col15, #T_a8746_row1_col16, #T_a8746_row1_col41, #T_a8746_row1_col47, #T_a8746_row2_col21, #T_a8746_row2_col27 {
#   background-color: #f5f9fe;
#   color: #000000;
# }
# #T_a8746_row1_col17 {
#   background-color: #b3d3e8;
#   color: #000000;
# }
# #T_a8746_row1_col18 {
#   background-color: #4f9bcb;
#   color: #f1f1f1;
# }
# #T_a8746_row2_col0, #T_a8746_row2_col1, #T_a8746_row2_col2, #T_a8746_row2_col3, #T_a8746_row2_col5, #T_a8746_row2_col6, #T_a8746_row2_col7, #T_a8746_row2_col8, #T_a8746_row2_col9 {
#   background-color: #aed1e7;
#   color: #000000;
# }
# #T_a8746_row2_col4 {
#   background-color: #b0d2e7;
#   color: #000000;
# }
# #T_a8746_row2_col10, #T_a8746_row2_col18 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_a8746_row2_col11, #T_a8746_row2_col17 {
#   background-color: #8abfdd;
#   color: #000000;
# }
# #T_a8746_row2_col12, #T_a8746_row2_col19 {
#   background-color: #e7f0fa;
#   color: #000000;
# }
# #T_a8746_row2_col15 {
#   background-color: #f2f8fd;
#   color: #000000;
# }
# #T_a8746_row2_col40, #T_a8746_row2_col48 {
#   background-color: #f0f6fd;
#   color: #000000;
# }
# </style>
# <table id="T_a8746">
#   <caption>KMeans Cluster Summary</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a8746_level0_col0" class="col_heading level0 col0" colspan="10">count</th>
#       <th id="T_a8746_level0_col10" class="col_heading level0 col10" colspan="10">max</th>
#       <th id="T_a8746_level0_col20" class="col_heading level0 col20" colspan="10">mean</th>
#       <th id="T_a8746_level0_col30" class="col_heading level0 col30" colspan="10">min</th>
#       <th id="T_a8746_level0_col40" class="col_heading level0 col40" colspan="10">std</th>
#     </tr>
#     <tr>
#       <th class="blank level1" >&nbsp;</th>
#       <th id="T_a8746_level1_col0" class="col_heading level1 col0" >adjmou</th>
#       <th id="T_a8746_level1_col1" class="col_heading level1 col1" >adjqty</th>
#       <th id="T_a8746_level1_col2" class="col_heading level1 col2" >adjrev</th>
#       <th id="T_a8746_level1_col3" class="col_heading level1 col3" >avg3mou</th>
#       <th id="T_a8746_level1_col4" class="col_heading level1 col4" >avg6mou</th>
#       <th id="T_a8746_level1_col5" class="col_heading level1 col5" >avgmou</th>
#       <th id="T_a8746_level1_col6" class="col_heading level1 col6" >mou_Mean</th>
#       <th id="T_a8746_level1_col7" class="col_heading level1 col7" >totcalls</th>
#       <th id="T_a8746_level1_col8" class="col_heading level1 col8" >totmou</th>
#       <th id="T_a8746_level1_col9" class="col_heading level1 col9" >totrev</th>
#       <th id="T_a8746_level1_col10" class="col_heading level1 col10" >adjmou</th>
#       <th id="T_a8746_level1_col11" class="col_heading level1 col11" >adjqty</th>
#       <th id="T_a8746_level1_col12" class="col_heading level1 col12" >adjrev</th>
#       <th id="T_a8746_level1_col13" class="col_heading level1 col13" >avg3mou</th>
#       <th id="T_a8746_level1_col14" class="col_heading level1 col14" >avg6mou</th>
#       <th id="T_a8746_level1_col15" class="col_heading level1 col15" >avgmou</th>
#       <th id="T_a8746_level1_col16" class="col_heading level1 col16" >mou_Mean</th>
#       <th id="T_a8746_level1_col17" class="col_heading level1 col17" >totcalls</th>
#       <th id="T_a8746_level1_col18" class="col_heading level1 col18" >totmou</th>
#       <th id="T_a8746_level1_col19" class="col_heading level1 col19" >totrev</th>
#       <th id="T_a8746_level1_col20" class="col_heading level1 col20" >adjmou</th>
#       <th id="T_a8746_level1_col21" class="col_heading level1 col21" >adjqty</th>
#       <th id="T_a8746_level1_col22" class="col_heading level1 col22" >adjrev</th>
#       <th id="T_a8746_level1_col23" class="col_heading level1 col23" >avg3mou</th>
#       <th id="T_a8746_level1_col24" class="col_heading level1 col24" >avg6mou</th>
#       <th id="T_a8746_level1_col25" class="col_heading level1 col25" >avgmou</th>
#       <th id="T_a8746_level1_col26" class="col_heading level1 col26" >mou_Mean</th>
#       <th id="T_a8746_level1_col27" class="col_heading level1 col27" >totcalls</th>
#       <th id="T_a8746_level1_col28" class="col_heading level1 col28" >totmou</th>
#       <th id="T_a8746_level1_col29" class="col_heading level1 col29" >totrev</th>
#       <th id="T_a8746_level1_col30" class="col_heading level1 col30" >adjmou</th>
#       <th id="T_a8746_level1_col31" class="col_heading level1 col31" >adjqty</th>
#       <th id="T_a8746_level1_col32" class="col_heading level1 col32" >adjrev</th>
#       <th id="T_a8746_level1_col33" class="col_heading level1 col33" >avg3mou</th>
#       <th id="T_a8746_level1_col34" class="col_heading level1 c

# %%
kmeans_top_vars = top_variable(df_kmeans_labeled, kmeans_labels)
kmeans_top_vars
# Out:
# {0: ['totmou',
#   'adjmou',
#   'totcalls',
#   'adjqty',
#   'totrev',
#   'adjrev',
#   'avg3mou',
#   'mou_Mean',
#   'avg6mou',
#   'avgmou'],
#  1: ['totmou',
#   'adjmou',
#   'totcalls',
#   'adjqty',
#   'totrev',
#   'adjrev',
#   'avg3mou',
#   'mou_Mean',
#   'avg6mou',
#   'avgmou'],
#  2: ['totmou',
#   'adjmou',
#   'totcalls',
#   'adjqty',
#   'totrev',
#   'adjrev',
#   'avg3mou',
#   'mou_Mean',
#   'avg6mou',
#   'avgmou']}

# %%
plot_pca(X, kmeans_labels)

# %%
top_feats_kmeans = list(set(sum(kmeans_top_vars.values(), [])))

# %%
plot_cluster_heatmap(df_kmeans_labeled, kmeans_labels, top_feats_kmeans)

# %%
plot_feature_boxplots(df_kmeans_labeled, kmeans_labels, top_feats_kmeans[:5])
# Out:
# C:\Users\Eden Thomas\AppData\Local\Temp\ipykernel_27704\3435183386.py:7: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x="cluster", y=feature, data=df, palette="tab10")
# C:\Users\Eden Thomas\AppData\Local\Temp\ipykernel_27704\3435183386.py:7: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x="cluster", y=feature, data=df, palette="tab10")
# C:\Users\Eden Thomas\AppData\Local\Temp\ipykernel_27704\3435183386.py:7: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x="cluster", y=feature, data=df, palette="tab10")
# C:\Users\Eden Thomas\AppData\Local\Temp\ipykernel_27704\3435183386.py:7: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x="cluster", y=feature, data=df, palette="tab10")
# C:\Users\Eden Thomas\AppData\Local\Temp\ipykernel_27704\3435183386.py:7: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x="cluster", y=feature, data=df, palette="tab10")

# %%
plot_parallel_coordinates(df_kmeans_labeled, kmeans_labels, top_feats_kmeans)

# %%
plot_radar_chart(df_kmeans_labeled, kmeans_labels, top_feats_kmeans[:6])

# %% [markdown]
# ## GMM

# %%
gmm = GaussianMixture(n_components=3, random_state=RANDOM_STATE)
gmm_labels = gmm.fit_predict(X)

# %%
gmm_metrics = clustering_metrics(X, gmm_labels)
gmm_metrics
# Out:
# {'silhouette': 0.28261570960757876,
#  'davies': 1.5129731717346946,
#  'calinski': 26350.03339143268}

# %%
df_gmm_labeled = df_original.copy()
df_gmm_labeled["cluster"] = gmm_labels

# %%
gmm_summary = cluster_summary(df_gmm_labeled, gmm_labels)
show_summary(gmm_summary, caption="GMM Cluster Summary")
# Out:
# <style type="text/css">
# #T_3b8b2_row0_col0, #T_3b8b2_row0_col1, #T_3b8b2_row0_col2, #T_3b8b2_row0_col3, #T_3b8b2_row0_col5, #T_3b8b2_row0_col6, #T_3b8b2_row0_col7, #T_3b8b2_row0_col8, #T_3b8b2_row0_col9 {
#   background-color: #eaf3fb;
#   color: #000000;
# }
# #T_3b8b2_row0_col4 {
#   background-color: #ebf3fb;
#   color: #000000;
# }
# #T_3b8b2_row0_col10 {
#   background-color: #084990;
#   color: #f1f1f1;
# }
# #T_3b8b2_row0_col11 {
#   background-color: #8dc1dd;
#   color: #000000;
# }
# #T_3b8b2_row0_col12, #T_3b8b2_row0_col19 {
#   background-color: #e0ecf8;
#   color: #000000;
# }
# #T_3b8b2_row0_col13, #T_3b8b2_row2_col13, #T_3b8b2_row2_col16, #T_3b8b2_row2_col20 {
#   background-color: #f1f7fd;
#   color: #000000;
# }
# #T_3b8b2_row0_col14, #T_3b8b2_row0_col15, #T_3b8b2_row2_col14 {
#   background-color: #f2f7fd;
#   color: #000000;
# }
# #T_3b8b2_row0_col16 {
#   background-color: #edf4fc;
#   color: #000000;
# }
# #T_3b8b2_row0_col17 {
#   background-color: #8cc0dd;
#   color: #000000;
# }
# #T_3b8b2_row0_col18 {
#   background-color: #08488e;
#   color: #f1f1f1;
# }
# #T_3b8b2_row0_col20, #T_3b8b2_row0_col28 {
#   background-color: #eff6fc;
#   color: #000000;
# }
# #T_3b8b2_row0_col21, #T_3b8b2_row0_col27, #T_3b8b2_row0_col41, #T_3b8b2_row1_col13, #T_3b8b2_row1_col15, #T_3b8b2_row1_col20, #T_3b8b2_row1_col28, #T_3b8b2_row2_col41, #T_3b8b2_row2_col47 {
#   background-color: #f4f9fe;
#   color: #000000;
# }
# #T_3b8b2_row0_col22, #T_3b8b2_row0_col29, #T_3b8b2_row0_col42, #T_3b8b2_row0_col49, #T_3b8b2_row1_col21, #T_3b8b2_row1_col27, #T_3b8b2_row2_col22, #T_3b8b2_row2_col29 {
#   background-color: #f6faff;
#   color: #000000;
# }
# #T_3b8b2_row0_col23, #T_3b8b2_row0_col24, #T_3b8b2_row0_col25, #T_3b8b2_row0_col26, #T_3b8b2_row0_col30, #T_3b8b2_row0_col31, #T_3b8b2_row0_col32, #T_3b8b2_row0_col33, #T_3b8b2_row0_col34, #T_3b8b2_row0_col35, #T_3b8b2_row0_col36, #T_3b8b2_row0_col37, #T_3b8b2_row0_col38, #T_3b8b2_row0_col39, #T_3b8b2_row0_col43, #T_3b8b2_row0_col44, #T_3b8b2_row0_col45, #T_3b8b2_row0_col46, #T_3b8b2_row1_col22, #T_3b8b2_row1_col23, #T_3b8b2_row1_col24, #T_3b8b2_row1_col25, #T_3b8b2_row1_col26, #T_3b8b2_row1_col29, #T_3b8b2_row1_col30, #T_3b8b2_row1_col31, #T_3b8b2_row1_col32, #T_3b8b2_row1_col33, #T_3b8b2_row1_col34, #T_3b8b2_row1_col35, #T_3b8b2_row1_col36, #T_3b8b2_row1_col37, #T_3b8b2_row1_col38, #T_3b8b2_row1_col39, #T_3b8b2_row1_col42, #T_3b8b2_row1_col43, #T_3b8b2_row1_col44, #T_3b8b2_row1_col45, #T_3b8b2_row1_col46, #T_3b8b2_row1_col49, #T_3b8b2_row2_col23, #T_3b8b2_row2_col24, #T_3b8b2_row2_col25, #T_3b8b2_row2_col26, #T_3b8b2_row2_col30, #T_3b8b2_row2_col31, #T_3b8b2_row2_col32, #T_3b8b2_row2_col33, #T_3b8b2_row2_col34, #T_3b8b2_row2_col35, #T_3b8b2_row2_col36, #T_3b8b2_row2_col37, #T_3b8b2_row2_col38, #T_3b8b2_row2_col39, #T_3b8b2_row2_col42, #T_3b8b2_row2_col43, #T_3b8b2_row2_col44, #T_3b8b2_row2_col45, #T_3b8b2_row2_col46, #T_3b8b2_row2_col49 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_3b8b2_row0_col40, #T_3b8b2_row0_col48, #T_3b8b2_row1_col12, #T_3b8b2_row1_col19 {
#   background-color: #eef5fc;
#   color: #000000;
# }
# #T_3b8b2_row0_col47 {
#   background-color: #f3f8fe;
#   color: #000000;
# }
# #T_3b8b2_row1_col0, #T_3b8b2_row1_col1, #T_3b8b2_row1_col2, #T_3b8b2_row1_col3, #T_3b8b2_row1_col5, #T_3b8b2_row1_col6, #T_3b8b2_row1_col7, #T_3b8b2_row1_col8, #T_3b8b2_row1_col9 {
#   background-color: #e6f0f9;
#   color: #000000;
# }
# #T_3b8b2_row1_col4, #T_3b8b2_row2_col12, #T_3b8b2_row2_col19 {
#   background-color: #e7f0fa;
#   color: #000000;
# }
# #T_3b8b2_row1_col10 {
#   background-color: #519ccc;
#   color: #f1f1f1;
# }
# #T_3b8b2_row1_col11 {
#   background-color: #b4d3e9;
#   color: #000000;
# }
# #T_3b8b2_row1_col14, #T_3b8b2_row1_col16, #T_3b8b2_row2_col21, #T_3b8b2_row2_col27 {
#   background-color: #f5f9fe;
#   color: #000000;
# }
# #T_3b8b2_row1_col17 {
#   background-color: #b3d3e8;
#   color: #000000;
# }
# #T_3b8b2_row1_col18 {
#   background-color: #4f9bcb;
#   color: #f1f1f1;
# }
# #T_3b8b2_row1_col40, #T_3b8b2_row1_col48, #T_3b8b2_row2_col15 {
#   background-color: #f2f8fd;
#   color: #000000;
# }
# #T_3b8b2_row1_col41, #T_3b8b2_row1_col47 {
#   background-color: #f5fafe;
#   color: #000000;
# }
# #T_3b8b2_row2_col0, #T_3b8b2_row2_col1, #T_3b8b2_row2_col2, #T_3b8b2_row2_col3, #T_3b8b2_row2_col5, #T_3b8b2_row2_col6, #T_3b8b2_row2_col7, #T_3b8b2_row2_col8, #T_3b8b2_row2_col9 {
#   background-color: #bed8ec;
#   color: #000000;
# }
# #T_3b8b2_row2_col4 {
#   background-color: #bfd8ed;
#   color: #000000;
# }
# #T_3b8b2_row2_col10, #T_3b8b2_row2_col18 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_3b8b2_row2_col11, #T_3b8b2_row2_col17 {
#   background-color: #8abfdd;
#   color: #000000;
# }
# #T_3b8b2_row2_col28, #T_3b8b2_row2_col40, #T_3b8b2_row2_col48 {
#   background-color: #f0f6fd;
#   color: #000000;
# }
# </style>
# <table id="T_3b8b2">
#   <caption>GMM Cluster Summary</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_3b8b2_level0_col0" class="col_heading level0 col0" colspan="10">count</th>
#       <th id="T_3b8b2_level0_col10" class="col_heading level0 col10" colspan="10">max</th>
#       <th id="T_3b8b2_level0_col20" class="col_heading level0 col20" colspan="10">mean</th>
#       <th id="T_3b8b2_level0_col30" class="col_heading level0 col30" colspan="10">min</th>
#       <th id="T_3b8b2_level0_col40" class="col_heading level0 col40" colspan="10">std</th>
#     </tr>
#     <tr>
#       <th class="blank level1" >&nbsp;</th>
#       <th id="T_3b8b2_level1_col0" class="col_heading level1 col0" >adjmou</th>
#       <th id="T_3b8b2_level1_col1" class="col_heading level1 col1" >adjqty</th>
#       <th id="T_3b8b2_level1_col2" class="col_heading level1 col2" >adjrev</th>
#       <th id="T_3b8b2_level1_col3" class="col_heading level1 col3" >avg3mou</th>
#       <th id="T_3b8b2_level1_col4" class="col_heading level1 col4" >avg6mou</th>
#       <th id="T_3b8b2_level1_col5" class="col_heading level1 col5" >avgmou</th>
#       <th id="T_3b8b2_level1_col6" class="col_heading level1 col6" >mou_Mean</th>
#       <th id="T_3b8b2_level1_col7" class="col_heading level1 col7" >totcalls</th>
#       <th id="T_3b8b2_level1_col8" class="col_heading level1 col8" >totmou</th>
#       <th id="T_3b8b2_level1_col9" class="col_heading level1 col9" >totrev</th>
#       <th id="T_3b8b2_level1_col10" class="col_heading level1 col10" >adjmou</th>
#       <th id="T_3b8b2_level1_col11" class="col_heading level1 col11" >adjqty</th>
#       <th id="T_3b8b2_level1_col12" class="col_heading level1 col12" >adjrev</th>
#       <th id="T_3b8b2_level1_col13" class="col_heading level1 col13" >avg3mou</th>
#       <th id="T_3b8b2_level1_col14" class="col_heading level1 col14" >avg6mou</th>
#       <th id="T_3b8b2_level1_col15" class="col_heading level1 col15" >avgmou</th>
#       <th id="T_3b8b2_level1_col16" class="col_heading level1 col16" >mou_Mean</th>
#       <th id="T_3b8b2_level1_col17" class="col_heading level1 col17" >totcalls</th>
#       <th id="T_3b8b2_level1_col18" class="col_heading level1 col18" >totmou</th>
#       <th id="T_3b8b2_level1_col19" class="col_heading level1 col19" >totrev</th>
#       <th id="T_3b8b2_level1_col20" class="col_heading level1 col20" >adjmou</th>
#       <th id="T_3b8b2_level1_col21" class="col_heading level1 col21" >adjqty</th>
#       <th id="T_3b8b2_level1_col22" class="col_heading level1 col22" >adjrev</th>
#       <th id="T_3b8b2_level1_col23" class="col_heading level1 col23" >avg3mou</th>
#       <th id="T_3b8b2_level1_col24" class="col_heading level1 col24" >avg6mou</th>
#       <th id="T_3b8b2_level1_col25" class="col_heading level1 col25" >avgmou</th>
#       <th id="T_3b8b2_level1_col26" class="col_heading level1 col26" >mou_Mean</th>
#       <th id="T_3b8b2_level1_col27" class="col_heading level1 col27" >totcalls</th>
#       <th id="T_3b8b2_level1_col28" class="col_heading level1 col28" >totmou</th>
#       <th id="T_3b8b2_level1_col29" class="col_heading level1 col29" >totrev</th>
#       <th id="T_3b8b2_level1_col30" class="col_heading level1 col30" >adjmou</th>
#       <th id="T_3b8b2_level1_col31" class="col_heading level1 col31" >adjqty</th>
#       <th id="T_3b8b2_level1_col32" class="col_heading level1 col32" >adjrev</th>
# <style type="text/css">
# #T_3b8b2_row0_col0, #T_3b8b2_row0_col1, #T_3b8b2_row0_col2, #T_3b8b2_row0_col3, #T_3b8b2_row0_col5, #T_3b8b2_row0_col6, #T_3b8b2_row0_col7, #T_3b8b2_row0_col8, #T_3b8b2_row0_col9 {
#   background-color: #eaf3fb;
#   color: #000000;
# }
# #T_3b8b2_row0_col4 {
#   background-color: #ebf3fb;
#   color: #000000;
# }
# #T_3b8b2_row0_col10 {
#   background-color: #084990;
#   color: #f1f1f1;
# }
# #T_3b8b2_row0_col11 {
#   background-color: #8dc1dd;
#   color: #000000;
# }
# #T_3b8b2_row0_col12, #T_3b8b2_row0_col19 {
#   background-color: #e0ecf8;
#   color: #000000;
# }
# #T_3b8b2_row0_col13, #T_3b8b2_row2_col13, #T_3b8b2_row2_col16, #T_3b8b2_row2_col20 {
#   background-color: #f1f7fd;
#   color: #000000;
# }
# #T_3b8b2_row0_col14, #T_3b8b2_row0_col15, #T_3b8b2_row2_col14 {
#   background-color: #f2f7fd;
#   color: #000000;
# }
# #T_3b8b2_row0_col16 {
#   background-color: #edf4fc;
#   color: #000000;
# }
# #T_3b8b2_row0_col17 {
#   background-color: #8cc0dd;
#   color: #000000;
# }
# #T_3b8b2_row0_col18 {
#   background-color: #08488e;
#   color: #f1f1f1;
# }
# #T_3b8b2_row0_col20, #T_3b8b2_row0_col28 {
#   background-color: #eff6fc;
#   color: #000000;
# }
# #T_3b8b2_row0_col21, #T_3b8b2_row0_col27, #T_3b8b2_row0_col41, #T_3b8b2_row1_col13, #T_3b8b2_row1_col15, #T_3b8b2_row1_col20, #T_3b8b2_row1_col28, #T_3b8b2_row2_col41, #T_3b8b2_row2_col47 {
#   background-color: #f4f9fe;
#   color: #000000;
# }
# #T_3b8b2_row0_col22, #T_3b8b2_row0_col29, #T_3b8b2_row0_col42, #T_3b8b2_row0_col49, #T_3b8b2_row1_col21, #T_3b8b2_row1_col27, #T_3b8b2_row2_col22, #T_3b8b2_row2_col29 {
#   background-color: #f6faff;
#   color: #000000;
# }
# #T_3b8b2_row0_col23, #T_3b8b2_row0_col24, #T_3b8b2_row0_col25, #T_3b8b2_row0_col26, #T_3b8b2_row0_col30, #T_3b8b2_row0_col31, #T_3b8b2_row0_col32, #T_3b8b2_row0_col33, #T_3b8b2_row0_col34, #T_3b8b2_row0_col35, #T_3b8b2_row0_col36, #T_3b8b2_row0_col37, #T_3b8b2_row0_col38, #T_3b8b2_row0_col39, #T_3b8b2_row0_col43, #T_3b8b2_row0_col44, #T_3b8b2_row0_col45, #T_3b8b2_row0_col46, #T_3b8b2_row1_col22, #T_3b8b2_row1_col23, #T_3b8b2_row1_col24, #T_3b8b2_row1_col25, #T_3b8b2_row1_col26, #T_3b8b2_row1_col29, #T_3b8b2_row1_col30, #T_3b8b2_row1_col31, #T_3b8b2_row1_col32, #T_3b8b2_row1_col33, #T_3b8b2_row1_col34, #T_3b8b2_row1_col35, #T_3b8b2_row1_col36, #T_3b8b2_row1_col37, #T_3b8b2_row1_col38, #T_3b8b2_row1_col39, #T_3b8b2_row1_col42, #T_3b8b2_row1_col43, #T_3b8b2_row1_col44, #T_3b8b2_row1_col45, #T_3b8b2_row1_col46, #T_3b8b2_row1_col49, #T_3b8b2_row2_col23, #T_3b8b2_row2_col24, #T_3b8b2_row2_col25, #T_3b8b2_row2_col26, #T_3b8b2_row2_col30, #T_3b8b2_row2_col31, #T_3b8b2_row2_col32, #T_3b8b2_row2_col33, #T_3b8b2_row2_col34, #T_3b8b2_row2_col35, #T_3b8b2_row2_col36, #T_3b8b2_row2_col37, #T_3b8b2_row2_col38, #T_3b8b2_row2_col39, #T_3b8b2_row2_col42, #T_3b8b2_row2_col43, #T_3b8b2_row2_col44, #T_3b8b2_row2_col45, #T_3b8b2_row2_col46, #T_3b8b2_row2_col49 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_3b8b2_row0_col40, #T_3b8b2_row0_col48, #T_3b8b2_row1_col12, #T_3b8b2_row1_col19 {
#   background-color: #eef5fc;
#   color: #000000;
# }
# #T_3b8b2_row0_col47 {
#   background-color: #f3f8fe;
#   color: #000000;
# }
# #T_3b8b2_row1_col0, #T_3b8b2_row1_col1, #T_3b8b2_row1_col2, #T_3b8b2_row1_col3, #T_3b8b2_row1_col5, #T_3b8b2_row1_col6, #T_3b8b2_row1_col7, #T_3b8b2_row1_col8, #T_3b8b2_row1_col9 {
#   background-color: #e6f0f9;
#   color: #000000;
# }
# #T_3b8b2_row1_col4, #T_3b8b2_row2_col12, #T_3b8b2_row2_col19 {
#   background-color: #e7f0fa;
#   color: #000000;
# }
# #T_3b8b2_row1_col10 {
#   background-color: #519ccc;
#   color: #f1f1f1;
# }
# #T_3b8b2_row1_col11 {
#   background-color: #b4d3e9;
#   color: #000000;
# }
# #T_3b8b2_row1_col14, #T_3b8b2_row1_col16, #T_3b8b2_row2_col21, #T_3b8b2_row2_col27 {
#   background-color: #f5f9fe;
#   color: #000000;
# }
# #T_3b8b2_row1_col17 {
#   background-color: #b3d3e8;
#   color: #000000;
# }
# #T_3b8b2_row1_col18 {
#   background-color: #4f9bcb;
#   color: #f1f1f1;
# }
# #T_3b8b2_row1_col40, #T_3b8b2_row1_col48, #T_3b8b2_row2_col15 {
#   background-color: #f2f8fd;
#   color: #000000;
# }
# #T_3b8b2_row1_col41, #T_3b8b2_row1_col47 {
#   background-color: #f5fafe;
#   color: #000000;
# }
# #T_3b8b2_row2_col0, #T_3b8b2_row2_col1, #T_3b8b2_row2_col2, #T_3b8b2_row2_col3, #T_3b8b2_row2_col5, #T_3b8b2_row2_col6, #T_3b8b2_row2_col7, #T_3b8b2_row2_col8, #T_3b8b2_row2_col9 {
#   background-color: #bed8ec;
#   color: #000000;
# }
# #T_3b8b2_row2_col4 {
#   background-color: #bfd8ed;
#   color: #000000;
# }
# #T_3b8b2_row2_col10, #T_3b8b2_row2_col18 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_3b8b2_row2_col11, #T_3b8b2_row2_col17 {
#   background-color: #8abfdd;
#   color: #000000;
# }
# #T_3b8b2_row2_col28, #T_3b8b2_row2_col40, #T_3b8b2_row2_col48 {
#   background-color: #f0f6fd;
#   color: #000000;
# }
# </style>
# <table id="T_3b8b2">
#   <caption>GMM Cluster Summary</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_3b8b2_level0_col0" class="col_heading level0 col0" colspan="10">count</th>
#       <th id="T_3b8b2_level0_col10" class="col_heading level0 col10" colspan="10">max</th>
#       <th id="T_3b8b2_level0_col20" class="col_heading level0 col20" colspan="10">mean</th>
#       <th id="T_3b8b2_level0_col30" class="col_heading level0 col30" colspan="10">min</th>
#       <th id="T_3b8b2_level0_col40" class="col_heading level0 col40" colspan="10">std</th>
#     </tr>
#     <tr>
#       <th class="blank level1" >&nbsp;</th>
#       <th id="T_3b8b2_level1_col0" class="col_heading level1 col0" >adjmou</th>
#       <th id="T_3b8b2_level1_col1" class="col_heading level1 col1" >adjqty</th>
#       <th id="T_3b8b2_level1_col2" class="col_heading level1 col2" >adjrev</th>
#       <th id="T_3b8b2_level1_col3" class="col_heading level1 col3" >avg3mou</th>
#       <th id="T_3b8b2_level1_col4" class="col_heading level1 col4" >avg6mou</th>
#       <th id="T_3b8b2_level1_col5" class="col_heading level1 col5" >avgmou</th>
#       <th id="T_3b8b2_level1_col6" class="col_heading level1 col6" >mou_Mean</th>
#       <th id="T_3b8b2_level1_col7" class="col_heading level1 col7" >totcalls</th>
#       <th id="T_3b8b2_level1_col8" class="col_heading level1 col8" >totmou</th>
#       <th id="T_3b8b2_level1_col9" class="col_heading level1 col9" >totrev</th>
#       <th id="T_3b8b2_level1_col10" class="col_heading level1 col10" >adjmou</th>
#       <th id="T_3b8b2_level1_col11" class="col_heading level1 col11" >adjqty</th>
#       <th id="T_3b8b2_level1_col12" class="col_heading level1 col12" >adjrev</th>
#       <th id="T_3b8b2_level1_col13" class="col_heading level1 col13" >avg3mou</th>
#       <th id="T_3b8b2_level1_col14" class="col_heading level1 col14" >avg6mou</th>
#       <th id="T_3b8b2_level1_col15" class="col_heading level1 col15" >avgmou</th>
#       <th id="T_3b8b2_level1_col16" class="col_heading level1 col16" >mou_Mean</th>
#       <th id="T_3b8b2_level1_col17" class="col_heading level1 col17" >totcalls</th>
#       <th id="T_3b8b2_level1_col18" class="col_heading level1 col18" >totmou</th>
#       <th id="T_3b8b2_level1_col19" class="col_heading level1 col19" >totrev</th>
#       <th id="T_3b8b2_level1_col20" class="col_heading level1 col20" >adjmou</th>
#       <th id="T_3b8b2_level1_col21" class="col_heading level1 col21" >adjqty</th>
#       <th id="T_3b8b2_level1_col22" class="col_heading level1 col22" >adjrev</th>
#       <th id="T_3b8b2_level1_col23" class="col_heading level1 col23" >avg3mou</th>
#       <th id="T_3b8b2_level1_col24" class="col_heading level1 col24" >avg6mou</th>
#       <th id="T_3b8b2_level1_col25" class="col_heading level1 col25" >avgmou</th>
#       <th id="T_3b8b2_level1_col26" class="col_heading level1 col26" >mou_Mean</th>
#       <th id="T_3b8b2_level1_col27" class="col_heading level1 col27" >totcalls</th>
#       <th id="T_3b8b2_level1_col28" class="col_heading level1 col28" >totmou</th>
#       <th id="T_3b8b2_level1_col29" class="col_heading level1 col29" >totrev</th>
#       <th id="T_3b8b2_level1_col30" class="col_heading level1 col30" >adjmou</th>
#       <th id="T_3b8b2_level1_col31" class="col_heading level1 col31" >adjqty</th>
#       <th id="T_3b8b2_level1_col32" class="col_heading level1 col32" >adjrev</th>

# %%
gmm_top_vars = top_variable(df_gmm_labeled, gmm_labels)
gmm_top_vars
# Out:
# {0: ['totmou',
#   'adjmou',
#   'totcalls',
#   'adjqty',
#   'totrev',
#   'adjrev',
#   'avg3mou',
#   'mou_Mean',
#   'avg6mou',
#   'avgmou'],
#  1: ['totmou',
#   'adjmou',
#   'totcalls',
#   'adjqty',
#   'totrev',
#   'adjrev',
#   'avg3mou',
#   'avg6mou',
#   'mou_Mean',
#   'avgmou'],
#  2: ['totmou',
#   'adjmou',
#   'totcalls',
#   'adjqty',
#   'totrev',
#   'adjrev',
#   'avg3mou',
#   'mou_Mean',
#   'avg6mou',
#   'avgmou']}

# %%
plot_pca(X, gmm_labels)

# %%
top_feats_gmm = list(set(sum(gmm_top_vars.values(), [])))

# %%
plot_cluster_heatmap(df_gmm_labeled, gmm_labels, top_feats_gmm)

# %%
plot_feature_boxplots(df_gmm_labeled, gmm_labels, top_feats_gmm[:5])
# Out:
# C:\Users\Eden Thomas\AppData\Local\Temp\ipykernel_27704\3435183386.py:7: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x="cluster", y=feature, data=df, palette="tab10")
# C:\Users\Eden Thomas\AppData\Local\Temp\ipykernel_27704\3435183386.py:7: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x="cluster", y=feature, data=df, palette="tab10")
# C:\Users\Eden Thomas\AppData\Local\Temp\ipykernel_27704\3435183386.py:7: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x="cluster", y=feature, data=df, palette="tab10")
# C:\Users\Eden Thomas\AppData\Local\Temp\ipykernel_27704\3435183386.py:7: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x="cluster", y=feature, data=df, palette="tab10")
# C:\Users\Eden Thomas\AppData\Local\Temp\ipykernel_27704\3435183386.py:7: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x="cluster", y=feature, data=df, palette="tab10")

# %%
plot_parallel_coordinates(df_gmm_labeled, gmm_labels, top_feats_gmm)

# %% [markdown]
# ## BIRCH

# %%
birch_model = Birch(n_clusters=None, threshold=5)
birch_sub_labels = birch_model.fit_predict(X)
birch_centers = birch_model.subcluster_centers_

# %%
k_final = 3
km_on_birch = KMeans(n_clusters=k_final, random_state=RANDOM_STATE)
birch_final_labels = km_on_birch.fit_predict(birch_centers)
birch_labels = np.array([birch_final_labels[i] for i in birch_sub_labels])

# %%
birch_metrics = clustering_metrics(X, birch_labels)
birch_metrics
# Out:
# {'silhouette': 0.3331546341657007,
#  'davies': 1.917513511838288,
#  'calinski': 14383.170019166315}

# %%
df_birch_labeled = df_original.copy()
df_birch_labeled["cluster"] = birch_labels

# %%
birch_summary = cluster_summary(df_birch_labeled, birch_labels)
show_summary(birch_summary, caption="Birch Cluster Summary")
# Out:
# <style type="text/css">
# #T_e3bbc_row0_col0, #T_e3bbc_row0_col1, #T_e3bbc_row0_col2, #T_e3bbc_row0_col3, #T_e3bbc_row0_col5, #T_e3bbc_row0_col6, #T_e3bbc_row0_col7, #T_e3bbc_row0_col8, #T_e3bbc_row0_col9 {
#   background-color: #a3cce3;
#   color: #000000;
# }
# #T_e3bbc_row0_col4 {
#   background-color: #a5cde3;
#   color: #000000;
# }
# #T_e3bbc_row0_col10, #T_e3bbc_row0_col18 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_e3bbc_row0_col11, #T_e3bbc_row0_col17 {
#   background-color: #97c6df;
#   color: #000000;
# }
# #T_e3bbc_row0_col12, #T_e3bbc_row0_col19 {
#   background-color: #e7f0fa;
#   color: #000000;
# }
# #T_e3bbc_row0_col13, #T_e3bbc_row0_col14, #T_e3bbc_row0_col20, #T_e3bbc_row0_col28, #T_e3bbc_row2_col14, #T_e3bbc_row2_col15, #T_e3bbc_row2_col41, #T_e3bbc_row2_col47 {
#   background-color: #f2f7fd;
#   color: #000000;
# }
# #T_e3bbc_row0_col15, #T_e3bbc_row1_col13, #T_e3bbc_row2_col0, #T_e3bbc_row2_col1, #T_e3bbc_row2_col2, #T_e3bbc_row2_col3, #T_e3bbc_row2_col5, #T_e3bbc_row2_col6, #T_e3bbc_row2_col7, #T_e3bbc_row2_col8, #T_e3bbc_row2_col9, #T_e3bbc_row2_col21, #T_e3bbc_row2_col27 {
#   background-color: #f2f8fd;
#   color: #000000;
# }
# #T_e3bbc_row0_col16, #T_e3bbc_row0_col40, #T_e3bbc_row0_col48, #T_e3bbc_row2_col13, #T_e3bbc_row2_col16 {
#   background-color: #f1f7fd;
#   color: #000000;
# }
# #T_e3bbc_row0_col21, #T_e3bbc_row0_col27 {
#   background-color: #f5fafe;
#   color: #000000;
# }
# #T_e3bbc_row0_col22, #T_e3bbc_row0_col29, #T_e3bbc_row1_col22, #T_e3bbc_row1_col29, #T_e3bbc_row2_col22, #T_e3bbc_row2_col23, #T_e3bbc_row2_col24, #T_e3bbc_row2_col25, #T_e3bbc_row2_col26, #T_e3bbc_row2_col29, #T_e3bbc_row2_col42, #T_e3bbc_row2_col49 {
#   background-color: #f6faff;
#   color: #000000;
# }
# #T_e3bbc_row0_col23, #T_e3bbc_row0_col24, #T_e3bbc_row0_col25, #T_e3bbc_row0_col26, #T_e3bbc_row0_col30, #T_e3bbc_row0_col31, #T_e3bbc_row0_col32, #T_e3bbc_row0_col33, #T_e3bbc_row0_col34, #T_e3bbc_row0_col35, #T_e3bbc_row0_col36, #T_e3bbc_row0_col37, #T_e3bbc_row0_col38, #T_e3bbc_row0_col39, #T_e3bbc_row0_col42, #T_e3bbc_row0_col43, #T_e3bbc_row0_col44, #T_e3bbc_row0_col45, #T_e3bbc_row0_col46, #T_e3bbc_row0_col49, #T_e3bbc_row1_col23, #T_e3bbc_row1_col24, #T_e3bbc_row1_col25, #T_e3bbc_row1_col26, #T_e3bbc_row1_col30, #T_e3bbc_row1_col31, #T_e3bbc_row1_col32, #T_e3bbc_row1_col33, #T_e3bbc_row1_col34, #T_e3bbc_row1_col35, #T_e3bbc_row1_col36, #T_e3bbc_row1_col37, #T_e3bbc_row1_col38, #T_e3bbc_row1_col39, #T_e3bbc_row1_col42, #T_e3bbc_row1_col43, #T_e3bbc_row1_col44, #T_e3bbc_row1_col45, #T_e3bbc_row1_col46, #T_e3bbc_row1_col49, #T_e3bbc_row2_col30, #T_e3bbc_row2_col31, #T_e3bbc_row2_col32, #T_e3bbc_row2_col33, #T_e3bbc_row2_col34, #T_e3bbc_row2_col35, #T_e3bbc_row2_col36, #T_e3bbc_row2_col37, #T_e3bbc_row2_col38, #T_e3bbc_row2_col39, #T_e3bbc_row2_col43, #T_e3bbc_row2_col44, #T_e3bbc_row2_col45, #T_e3bbc_row2_col46 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_e3bbc_row0_col41, #T_e3bbc_row0_col47, #T_e3bbc_row1_col21, #T_e3bbc_row1_col27 {
#   background-color: #f5f9fe;
#   color: #000000;
# }
# #T_e3bbc_row1_col0, #T_e3bbc_row1_col1, #T_e3bbc_row1_col2, #T_e3bbc_row1_col3, #T_e3bbc_row1_col5, #T_e3bbc_row1_col6, #T_e3bbc_row1_col7, #T_e3bbc_row1_col8, #T_e3bbc_row1_col9 {
#   background-color: #eef5fc;
#   color: #000000;
# }
# #T_e3bbc_row1_col4 {
#   background-color: #eff6fc;
#   color: #000000;
# }
# #T_e3bbc_row1_col10 {
#   background-color: #4e9acb;
#   color: #f1f1f1;
# }
# #T_e3bbc_row1_col11 {
#   background-color: #bed8ec;
#   color: #000000;
# }
# #T_e3bbc_row1_col12, #T_e3bbc_row1_col16, #T_e3bbc_row1_col19 {
#   background-color: #edf4fc;
#   color: #000000;
# }
# #T_e3bbc_row1_col14, #T_e3bbc_row1_col15, #T_e3bbc_row2_col4 {
#   background-color: #f3f8fe;
#   color: #000000;
# }
# #T_e3bbc_row1_col17 {
#   background-color: #bdd7ec;
#   color: #000000;
# }
# #T_e3bbc_row1_col18 {
#   background-color: #4d99ca;
#   color: #f1f1f1;
# }
# #T_e3bbc_row1_col20, #T_e3bbc_row1_col28, #T_e3bbc_row1_col40, #T_e3bbc_row1_col48 {
#   background-color: #f0f6fd;
#   color: #000000;
# }
# #T_e3bbc_row1_col41, #T_e3bbc_row1_col47 {
#   background-color: #f4f9fe;
#   color: #000000;
# }
# #T_e3bbc_row2_col10 {
#   background-color: #084990;
#   color: #f1f1f1;
# }
# #T_e3bbc_row2_col11, #T_e3bbc_row2_col17 {
#   background-color: #8abfdd;
#   color: #000000;
# }
# #T_e3bbc_row2_col12, #T_e3bbc_row2_col19 {
#   background-color: #e0ecf8;
#   color: #000000;
# }
# #T_e3bbc_row2_col18 {
#   background-color: #08488e;
#   color: #f1f1f1;
# }
# #T_e3bbc_row2_col20, #T_e3bbc_row2_col28 {
#   background-color: #eaf3fb;
#   color: #000000;
# }
# #T_e3bbc_row2_col40, #T_e3bbc_row2_col48 {
#   background-color: #ebf3fb;
#   color: #000000;
# }
# </style>
# <table id="T_e3bbc">
#   <caption>Birch Cluster Summary</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e3bbc_level0_col0" class="col_heading level0 col0" colspan="10">count</th>
#       <th id="T_e3bbc_level0_col10" class="col_heading level0 col10" colspan="10">max</th>
#       <th id="T_e3bbc_level0_col20" class="col_heading level0 col20" colspan="10">mean</th>
#       <th id="T_e3bbc_level0_col30" class="col_heading level0 col30" colspan="10">min</th>
#       <th id="T_e3bbc_level0_col40" class="col_heading level0 col40" colspan="10">std</th>
#     </tr>
#     <tr>
#       <th class="blank level1" >&nbsp;</th>
#       <th id="T_e3bbc_level1_col0" class="col_heading level1 col0" >adjmou</th>
#       <th id="T_e3bbc_level1_col1" class="col_heading level1 col1" >adjqty</th>
#       <th id="T_e3bbc_level1_col2" class="col_heading level1 col2" >adjrev</th>
#       <th id="T_e3bbc_level1_col3" class="col_heading level1 col3" >avg3mou</th>
#       <th id="T_e3bbc_level1_col4" class="col_heading level1 col4" >avg6mou</th>
#       <th id="T_e3bbc_level1_col5" class="col_heading level1 col5" >avgmou</th>
#       <th id="T_e3bbc_level1_col6" class="col_heading level1 col6" >mou_Mean</th>
#       <th id="T_e3bbc_level1_col7" class="col_heading level1 col7" >totcalls</th>
#       <th id="T_e3bbc_level1_col8" class="col_heading level1 col8" >totmou</th>
#       <th id="T_e3bbc_level1_col9" class="col_heading level1 col9" >totrev</th>
#       <th id="T_e3bbc_level1_col10" class="col_heading level1 col10" >adjmou</th>
#       <th id="T_e3bbc_level1_col11" class="col_heading level1 col11" >adjqty</th>
#       <th id="T_e3bbc_level1_col12" class="col_heading level1 col12" >adjrev</th>
#       <th id="T_e3bbc_level1_col13" class="col_heading level1 col13" >avg3mou</th>
#       <th id="T_e3bbc_level1_col14" class="col_heading level1 col14" >avg6mou</th>
#       <th id="T_e3bbc_level1_col15" class="col_heading level1 col15" >avgmou</th>
#       <th id="T_e3bbc_level1_col16" class="col_heading level1 col16" >mou_Mean</th>
#       <th id="T_e3bbc_level1_col17" class="col_heading level1 col17" >totcalls</th>
#       <th id="T_e3bbc_level1_col18" class="col_heading level1 col18" >totmou</th>
#       <th id="T_e3bbc_level1_col19" class="col_heading level1 col19" >totrev</th>
#       <th id="T_e3bbc_level1_col20" class="col_heading level1 col20" >adjmou</th>
#       <th id="T_e3bbc_level1_col21" class="col_heading level1 col21" >adjqty</th>
#       <th id="T_e3bbc_level1_col22" class="col_heading level1 col22" >adjrev</th>
#       <th id="T_e3bbc_level1_col23" class="col_heading level1 col23" >avg3mou</th>
#       <th id="T_e3bbc_level1_col24" class="col_heading level1 col24" >avg6mou</th>
#       <th id="T_e3bbc_level1_col25" class="col_heading level1 col25" >avgmou</th>
#       <th id="T_e3bbc_level1_col26" class="col_heading level1 col26" >mou_Mean</th>
#       <th id="T_e3bbc_level1_col27" class="col_heading level1 col27" >totcalls</th>
#       <th id="T_e3bbc_level1_col28" class="col_heading level1 col28" >totmou</th>
#       <th id="T_e3bbc_level1_col29" class="col_heading level1 col29" >totrev</th>
#       <th id="T_e3bbc_level1_col30" class="col_heading level1 col30" >adjmou</th>
#       <th id="T_e3bbc_level1_col31" class="col_heading level1 col31" >adjqty</th>
#       <th id="T_e3bbc_level1_col32" class="col_heading level1 col32" >adjrev</th>
#       <th id="T_e3bbc_level1_col33" class="col_heading level1 col33" >avg3mou</th>
#       <th id="
# <style type="text/css">
# #T_e3bbc_row0_col0, #T_e3bbc_row0_col1, #T_e3bbc_row0_col2, #T_e3bbc_row0_col3, #T_e3bbc_row0_col5, #T_e3bbc_row0_col6, #T_e3bbc_row0_col7, #T_e3bbc_row0_col8, #T_e3bbc_row0_col9 {
#   background-color: #a3cce3;
#   color: #000000;
# }
# #T_e3bbc_row0_col4 {
#   background-color: #a5cde3;
#   color: #000000;
# }
# #T_e3bbc_row0_col10, #T_e3bbc_row0_col18 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_e3bbc_row0_col11, #T_e3bbc_row0_col17 {
#   background-color: #97c6df;
#   color: #000000;
# }
# #T_e3bbc_row0_col12, #T_e3bbc_row0_col19 {
#   background-color: #e7f0fa;
#   color: #000000;
# }
# #T_e3bbc_row0_col13, #T_e3bbc_row0_col14, #T_e3bbc_row0_col20, #T_e3bbc_row0_col28, #T_e3bbc_row2_col14, #T_e3bbc_row2_col15, #T_e3bbc_row2_col41, #T_e3bbc_row2_col47 {
#   background-color: #f2f7fd;
#   color: #000000;
# }
# #T_e3bbc_row0_col15, #T_e3bbc_row1_col13, #T_e3bbc_row2_col0, #T_e3bbc_row2_col1, #T_e3bbc_row2_col2, #T_e3bbc_row2_col3, #T_e3bbc_row2_col5, #T_e3bbc_row2_col6, #T_e3bbc_row2_col7, #T_e3bbc_row2_col8, #T_e3bbc_row2_col9, #T_e3bbc_row2_col21, #T_e3bbc_row2_col27 {
#   background-color: #f2f8fd;
#   color: #000000;
# }
# #T_e3bbc_row0_col16, #T_e3bbc_row0_col40, #T_e3bbc_row0_col48, #T_e3bbc_row2_col13, #T_e3bbc_row2_col16 {
#   background-color: #f1f7fd;
#   color: #000000;
# }
# #T_e3bbc_row0_col21, #T_e3bbc_row0_col27 {
#   background-color: #f5fafe;
#   color: #000000;
# }
# #T_e3bbc_row0_col22, #T_e3bbc_row0_col29, #T_e3bbc_row1_col22, #T_e3bbc_row1_col29, #T_e3bbc_row2_col22, #T_e3bbc_row2_col23, #T_e3bbc_row2_col24, #T_e3bbc_row2_col25, #T_e3bbc_row2_col26, #T_e3bbc_row2_col29, #T_e3bbc_row2_col42, #T_e3bbc_row2_col49 {
#   background-color: #f6faff;
#   color: #000000;
# }
# #T_e3bbc_row0_col23, #T_e3bbc_row0_col24, #T_e3bbc_row0_col25, #T_e3bbc_row0_col26, #T_e3bbc_row0_col30, #T_e3bbc_row0_col31, #T_e3bbc_row0_col32, #T_e3bbc_row0_col33, #T_e3bbc_row0_col34, #T_e3bbc_row0_col35, #T_e3bbc_row0_col36, #T_e3bbc_row0_col37, #T_e3bbc_row0_col38, #T_e3bbc_row0_col39, #T_e3bbc_row0_col42, #T_e3bbc_row0_col43, #T_e3bbc_row0_col44, #T_e3bbc_row0_col45, #T_e3bbc_row0_col46, #T_e3bbc_row0_col49, #T_e3bbc_row1_col23, #T_e3bbc_row1_col24, #T_e3bbc_row1_col25, #T_e3bbc_row1_col26, #T_e3bbc_row1_col30, #T_e3bbc_row1_col31, #T_e3bbc_row1_col32, #T_e3bbc_row1_col33, #T_e3bbc_row1_col34, #T_e3bbc_row1_col35, #T_e3bbc_row1_col36, #T_e3bbc_row1_col37, #T_e3bbc_row1_col38, #T_e3bbc_row1_col39, #T_e3bbc_row1_col42, #T_e3bbc_row1_col43, #T_e3bbc_row1_col44, #T_e3bbc_row1_col45, #T_e3bbc_row1_col46, #T_e3bbc_row1_col49, #T_e3bbc_row2_col30, #T_e3bbc_row2_col31, #T_e3bbc_row2_col32, #T_e3bbc_row2_col33, #T_e3bbc_row2_col34, #T_e3bbc_row2_col35, #T_e3bbc_row2_col36, #T_e3bbc_row2_col37, #T_e3bbc_row2_col38, #T_e3bbc_row2_col39, #T_e3bbc_row2_col43, #T_e3bbc_row2_col44, #T_e3bbc_row2_col45, #T_e3bbc_row2_col46 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_e3bbc_row0_col41, #T_e3bbc_row0_col47, #T_e3bbc_row1_col21, #T_e3bbc_row1_col27 {
#   background-color: #f5f9fe;
#   color: #000000;
# }
# #T_e3bbc_row1_col0, #T_e3bbc_row1_col1, #T_e3bbc_row1_col2, #T_e3bbc_row1_col3, #T_e3bbc_row1_col5, #T_e3bbc_row1_col6, #T_e3bbc_row1_col7, #T_e3bbc_row1_col8, #T_e3bbc_row1_col9 {
#   background-color: #eef5fc;
#   color: #000000;
# }
# #T_e3bbc_row1_col4 {
#   background-color: #eff6fc;
#   color: #000000;
# }
# #T_e3bbc_row1_col10 {
#   background-color: #4e9acb;
#   color: #f1f1f1;
# }
# #T_e3bbc_row1_col11 {
#   background-color: #bed8ec;
#   color: #000000;
# }
# #T_e3bbc_row1_col12, #T_e3bbc_row1_col16, #T_e3bbc_row1_col19 {
#   background-color: #edf4fc;
#   color: #000000;
# }
# #T_e3bbc_row1_col14, #T_e3bbc_row1_col15, #T_e3bbc_row2_col4 {
#   background-color: #f3f8fe;
#   color: #000000;
# }
# #T_e3bbc_row1_col17 {
#   background-color: #bdd7ec;
#   color: #000000;
# }
# #T_e3bbc_row1_col18 {
#   background-color: #4d99ca;
#   color: #f1f1f1;
# }
# #T_e3bbc_row1_col20, #T_e3bbc_row1_col28, #T_e3bbc_row1_col40, #T_e3bbc_row1_col48 {
#   background-color: #f0f6fd;
#   color: #000000;
# }
# #T_e3bbc_row1_col41, #T_e3bbc_row1_col47 {
#   background-color: #f4f9fe;
#   color: #000000;
# }
# #T_e3bbc_row2_col10 {
#   background-color: #084990;
#   color: #f1f1f1;
# }
# #T_e3bbc_row2_col11, #T_e3bbc_row2_col17 {
#   background-color: #8abfdd;
#   color: #000000;
# }
# #T_e3bbc_row2_col12, #T_e3bbc_row2_col19 {
#   background-color: #e0ecf8;
#   color: #000000;
# }
# #T_e3bbc_row2_col18 {
#   background-color: #08488e;
#   color: #f1f1f1;
# }
# #T_e3bbc_row2_col20, #T_e3bbc_row2_col28 {
#   background-color: #eaf3fb;
#   color: #000000;
# }
# #T_e3bbc_row2_col40, #T_e3bbc_row2_col48 {
#   background-color: #ebf3fb;
#   color: #000000;
# }
# </style>
# <table id="T_e3bbc">
#   <caption>Birch Cluster Summary</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e3bbc_level0_col0" class="col_heading level0 col0" colspan="10">count</th>
#       <th id="T_e3bbc_level0_col10" class="col_heading level0 col10" colspan="10">max</th>
#       <th id="T_e3bbc_level0_col20" class="col_heading level0 col20" colspan="10">mean</th>
#       <th id="T_e3bbc_level0_col30" class="col_heading level0 col30" colspan="10">min</th>
#       <th id="T_e3bbc_level0_col40" class="col_heading level0 col40" colspan="10">std</th>
#     </tr>
#     <tr>
#       <th class="blank level1" >&nbsp;</th>
#       <th id="T_e3bbc_level1_col0" class="col_heading level1 col0" >adjmou</th>
#       <th id="T_e3bbc_level1_col1" class="col_heading level1 col1" >adjqty</th>
#       <th id="T_e3bbc_level1_col2" class="col_heading level1 col2" >adjrev</th>
#       <th id="T_e3bbc_level1_col3" class="col_heading level1 col3" >avg3mou</th>
#       <th id="T_e3bbc_level1_col4" class="col_heading level1 col4" >avg6mou</th>
#       <th id="T_e3bbc_level1_col5" class="col_heading level1 col5" >avgmou</th>
#       <th id="T_e3bbc_level1_col6" class="col_heading level1 col6" >mou_Mean</th>
#       <th id="T_e3bbc_level1_col7" class="col_heading level1 col7" >totcalls</th>
#       <th id="T_e3bbc_level1_col8" class="col_heading level1 col8" >totmou</th>
#       <th id="T_e3bbc_level1_col9" class="col_heading level1 col9" >totrev</th>
#       <th id="T_e3bbc_level1_col10" class="col_heading level1 col10" >adjmou</th>
#       <th id="T_e3bbc_level1_col11" class="col_heading level1 col11" >adjqty</th>
#       <th id="T_e3bbc_level1_col12" class="col_heading level1 col12" >adjrev</th>
#       <th id="T_e3bbc_level1_col13" class="col_heading level1 col13" >avg3mou</th>
#       <th id="T_e3bbc_level1_col14" class="col_heading level1 col14" >avg6mou</th>
#       <th id="T_e3bbc_level1_col15" class="col_heading level1 col15" >avgmou</th>
#       <th id="T_e3bbc_level1_col16" class="col_heading level1 col16" >mou_Mean</th>
#       <th id="T_e3bbc_level1_col17" class="col_heading level1 col17" >totcalls</th>
#       <th id="T_e3bbc_level1_col18" class="col_heading level1 col18" >totmou</th>
#       <th id="T_e3bbc_level1_col19" class="col_heading level1 col19" >totrev</th>
#       <th id="T_e3bbc_level1_col20" class="col_heading level1 col20" >adjmou</th>
#       <th id="T_e3bbc_level1_col21" class="col_heading level1 col21" >adjqty</th>
#       <th id="T_e3bbc_level1_col22" class="col_heading level1 col22" >adjrev</th>
#       <th id="T_e3bbc_level1_col23" class="col_heading level1 col23" >avg3mou</th>
#       <th id="T_e3bbc_level1_col24" class="col_heading level1 col24" >avg6mou</th>
#       <th id="T_e3bbc_level1_col25" class="col_heading level1 col25" >avgmou</th>
#       <th id="T_e3bbc_level1_col26" class="col_heading level1 col26" >mou_Mean</th>
#       <th id="T_e3bbc_level1_col27" class="col_heading level1 col27" >totcalls</th>
#       <th id="T_e3bbc_level1_col28" class="col_heading level1 col28" >totmou</th>
#       <th id="T_e3bbc_level1_col29" class="col_heading level1 col29" >totrev</th>
#       <th id="T_e3bbc_level1_col30" class="col_heading level1 col30" >adjmou</th>
#       <th id="T_e3bbc_level1_col31" class="col_heading level1 col31" >adjqty</th>
#       <th id="T_e3bbc_level1_col32" class="col_heading level1 col32" >adjrev</th>
#       <th id="T_e3bbc_level1_col33" class="col_heading level1 col33" >avg3mou</th>
#       <th id="

# %%
birch_top_vars = top_variable(df_birch_labeled, birch_labels)
birch_top_vars
# Out:
# {0: ['totmou',
#   'adjmou',
#   'totcalls',
#   'adjqty',
#   'totrev',
#   'adjrev',
#   'mou_Mean',
#   'avg3mou',
#   'avg6mou',
#   'avgmou'],
#  1: ['totmou',
#   'adjmou',
#   'totcalls',
#   'adjqty',
#   'totrev',
#   'adjrev',
#   'mou_Mean',
#   'avg3mou',
#   'avg6mou',
#   'avgmou'],
#  2: ['totmou',
#   'adjmou',
#   'totcalls',
#   'adjqty',
#   'totrev',
#   'adjrev',
#   'avg3mou',
#   'mou_Mean',
#   'avg6mou',
#   'avgmou']}

# %%
plot_pca(X, birch_labels)

# %%
top_feats_birch = list(set(sum(birch_top_vars.values(), [])))

# %%
plot_cluster_heatmap(df_birch_labeled, birch_labels, top_feats_birch)

# %%
plot_feature_boxplots(df_birch_labeled, birch_labels, top_feats_birch[:5])
# Out:
# C:\Users\Eden Thomas\AppData\Local\Temp\ipykernel_27704\3435183386.py:7: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x="cluster", y=feature, data=df, palette="tab10")
# C:\Users\Eden Thomas\AppData\Local\Temp\ipykernel_27704\3435183386.py:7: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x="cluster", y=feature, data=df, palette="tab10")
# C:\Users\Eden Thomas\AppData\Local\Temp\ipykernel_27704\3435183386.py:7: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x="cluster", y=feature, data=df, palette="tab10")
# C:\Users\Eden Thomas\AppData\Local\Temp\ipykernel_27704\3435183386.py:7: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x="cluster", y=feature, data=df, palette="tab10")
# C:\Users\Eden Thomas\AppData\Local\Temp\ipykernel_27704\3435183386.py:7: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x="cluster", y=feature, data=df, palette="tab10")

# %%
plot_parallel_coordinates(df_birch_labeled, birch_labels, top_feats_birch)

# %% [markdown]
# ## HDBSCAN

# %%
hdb = hdbscan.HDBSCAN(min_cluster_size=400, min_samples=None)
hdb_labels = hdb.fit_predict(X)
# Out:
# C:\Users\Eden Thomas\.conda\envs\thesis\Lib\site-packages\sklearn\utils\deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# C:\Users\Eden Thomas\.conda\envs\thesis\Lib\site-packages\sklearn\utils\deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(

# %%
hdb_metrics = clustering_metrics(X, hdb_labels)
hdb_metrics
# Out:
# {'silhouette': 0.14358956279992616,
#  'davies': 2.4061508606614206,
#  'calinski': 8107.326623455253}

# %%
df_hdb_labeled = df_original.copy()
df_hdb_labeled["cluster"] = hdb_labels

# %%
hdb_summary = cluster_summary(df_hdb_labeled, hdb_labels)
show_summary(hdb_summary, caption="HDBSCAN Cluster Summary")
# Out:
# <style type="text/css">
# #T_068d4_row0_col0, #T_068d4_row0_col1, #T_068d4_row0_col2, #T_068d4_row0_col3, #T_068d4_row0_col5, #T_068d4_row0_col6, #T_068d4_row0_col7, #T_068d4_row0_col8, #T_068d4_row0_col9 {
#   background-color: #e9f2fa;
#   color: #000000;
# }
# #T_068d4_row0_col4 {
#   background-color: #eaf2fb;
#   color: #000000;
# }
# #T_068d4_row0_col10, #T_068d4_row0_col18 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_068d4_row0_col11, #T_068d4_row0_col17 {
#   background-color: #8abfdd;
#   color: #000000;
# }
# #T_068d4_row0_col12, #T_068d4_row0_col19 {
#   background-color: #e0ecf8;
#   color: #000000;
# }
# #T_068d4_row0_col13, #T_068d4_row1_col20, #T_068d4_row1_col28, #T_068d4_row2_col20, #T_068d4_row2_col48, #T_068d4_row6_col48 {
#   background-color: #f1f7fd;
#   color: #000000;
# }
# #T_068d4_row0_col14, #T_068d4_row0_col15, #T_068d4_row1_col40, #T_068d4_row1_col48, #T_068d4_row2_col0, #T_068d4_row2_col1, #T_068d4_row2_col2, #T_068d4_row2_col3, #T_068d4_row2_col4, #T_068d4_row2_col5, #T_068d4_row2_col6, #T_068d4_row2_col7, #T_068d4_row2_col8, #T_068d4_row2_col9, #T_068d4_row2_col12, #T_068d4_row2_col19, #T_068d4_row2_col40, #T_068d4_row4_col20, #T_068d4_row4_col28, #T_068d4_row5_col12, #T_068d4_row5_col19, #T_068d4_row6_col20, #T_068d4_row6_col28, #T_068d4_row6_col40 {
#   background-color: #f2f7fd;
#   color: #000000;
# }
# #T_068d4_row0_col16 {
#   background-color: #edf4fc;
#   color: #000000;
# }
# #T_068d4_row0_col20, #T_068d4_row0_col28 {
#   background-color: #eef5fc;
#   color: #000000;
# }
# #T_068d4_row0_col21, #T_068d4_row0_col27, #T_068d4_row1_col12, #T_068d4_row3_col0, #T_068d4_row3_col1, #T_068d4_row3_col2, #T_068d4_row3_col3, #T_068d4_row3_col4, #T_068d4_row3_col5, #T_068d4_row3_col6, #T_068d4_row3_col7, #T_068d4_row3_col8, #T_068d4_row3_col9, #T_068d4_row5_col20, #T_068d4_row5_col28, #T_068d4_row6_col13 {
#   background-color: #f4f9fe;
#   color: #000000;
# }
# #T_068d4_row0_col22, #T_068d4_row0_col29, #T_068d4_row0_col42, #T_068d4_row0_col49, #T_068d4_row1_col29, #T_068d4_row2_col22, #T_068d4_row2_col29, #T_068d4_row3_col29, #T_068d4_row4_col0, #T_068d4_row4_col1, #T_068d4_row4_col2, #T_068d4_row4_col3, #T_068d4_row4_col4, #T_068d4_row4_col5, #T_068d4_row4_col6, #T_068d4_row4_col7, #T_068d4_row4_col8, #T_068d4_row4_col9, #T_068d4_row5_col21, #T_068d4_row5_col27, #T_068d4_row6_col22, #T_068d4_row6_col29 {
#   background-color: #f6faff;
#   color: #000000;
# }
# #T_068d4_row0_col23, #T_068d4_row0_col24, #T_068d4_row0_col25, #T_068d4_row0_col26, #T_068d4_row0_col30, #T_068d4_row0_col31, #T_068d4_row0_col32, #T_068d4_row0_col33, #T_068d4_row0_col34, #T_068d4_row0_col35, #T_068d4_row0_col36, #T_068d4_row0_col37, #T_068d4_row0_col38, #T_068d4_row0_col39, #T_068d4_row0_col43, #T_068d4_row0_col44, #T_068d4_row0_col45, #T_068d4_row0_col46, #T_068d4_row1_col0, #T_068d4_row1_col1, #T_068d4_row1_col2, #T_068d4_row1_col3, #T_068d4_row1_col4, #T_068d4_row1_col5, #T_068d4_row1_col6, #T_068d4_row1_col7, #T_068d4_row1_col8, #T_068d4_row1_col9, #T_068d4_row1_col22, #T_068d4_row1_col23, #T_068d4_row1_col24, #T_068d4_row1_col25, #T_068d4_row1_col26, #T_068d4_row1_col30, #T_068d4_row1_col31, #T_068d4_row1_col32, #T_068d4_row1_col33, #T_068d4_row1_col34, #T_068d4_row1_col35, #T_068d4_row1_col36, #T_068d4_row1_col37, #T_068d4_row1_col38, #T_068d4_row1_col39, #T_068d4_row1_col42, #T_068d4_row1_col43, #T_068d4_row1_col44, #T_068d4_row1_col45, #T_068d4_row1_col46, #T_068d4_row1_col49, #T_068d4_row2_col23, #T_068d4_row2_col24, #T_068d4_row2_col25, #T_068d4_row2_col26, #T_068d4_row2_col30, #T_068d4_row2_col31, #T_068d4_row2_col32, #T_068d4_row2_col33, #T_068d4_row2_col34, #T_068d4_row2_col35, #T_068d4_row2_col36, #T_068d4_row2_col37, #T_068d4_row2_col38, #T_068d4_row2_col39, #T_068d4_row2_col42, #T_068d4_row2_col43, #T_068d4_row2_col44, #T_068d4_row2_col45, #T_068d4_row2_col46, #T_068d4_row2_col49, #T_068d4_row3_col22, #T_068d4_row3_col23, #T_068d4_row3_col24, #T_068d4_row3_col25, #T_068d4_row3_col26, #T_068d4_row3_col30, #T_068d4_row3_col31, #T_068d4_row3_col32, #T_068d4_row3_col33, #T_068d4_row3_col34, #T_068d4_row3_col35, #T_068d4_row3_col36, #T_068d4_row3_col37, #T_068d4_row3_col38, #T_068d4_row3_col39, #T_068d4_row3_col42, #T_068d4_row3_col43, #T_068d4_row3_col44, #T_068d4_row3_col45, #T_068d4_row3_col46, #T_068d4_row3_col49, #T_068d4_row4_col22, #T_068d4_row4_col23, #T_068d4_row4_col24, #T_068d4_row4_col25, #T_068d4_row4_col26, #T_068d4_row4_col29, #T_068d4_row4_col30, #T_068d4_row4_col31, #T_068d4_row4_col32, #T_068d4_row4_col33, #T_068d4_row4_col34, #T_068d4_row4_col35, #T_068d4_row4_col36, #T_068d4_row4_col37, #T_068d4_row4_col38, #T_068d4_row4_col39, #T_068d4_row4_col42, #T_068d4_row4_col43, #T_068d4_row4_col44, #T_068d4_row4_col45, #T_068d4_row4_col46, #T_068d4_row4_col49, #T_068d4_row5_col22, #T_068d4_row5_col23, #T_068d4_row5_col24, #T_068d4_row5_col25, #T_068d4_row5_col26, #T_068d4_row5_col29, #T_068d4_row5_col30, #T_068d4_row5_col31, #T_068d4_row5_col32, #T_068d4_row5_col33, #T_068d4_row5_col34, #T_068d4_row5_col35, #T_068d4_row5_col36, #T_068d4_row5_col37, #T_068d4_row5_col38, #T_068d4_row5_col39, #T_068d4_row5_col42, #T_068d4_row5_col43, #T_068d4_row5_col44, #T_068d4_row5_col45, #T_068d4_row5_col46, #T_068d4_row5_col49, #T_068d4_row6_col23, #T_068d4_row6_col24, #T_068d4_row6_col25, #T_068d4_row6_col26, #T_068d4_row6_col30, #T_068d4_row6_col31, #T_068d4_row6_col32, #T_068d4_row6_col33, #T_068d4_row6_col34, #T_068d4_row6_col35, #T_068d4_row6_col36, #T_068d4_row6_col37, #T_068d4_row6_col38, #T_068d4_row6_col39, #T_068d4_row6_col42, #T_068d4_row6_col43, #T_068d4_row6_col44, #T_068d4_row6_col45, #T_068d4_row6_col46, #T_068d4_row6_col49 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_068d4_row0_col40, #T_068d4_row0_col48 {
#   background-color: #ecf4fb;
#   color: #000000;
# }
# #T_068d4_row0_col41, #T_068d4_row0_col47, #T_068d4_row3_col20, #T_068d4_row3_col28, #T_068d4_row3_col40, #T_068d4_row3_col48, #T_068d4_row4_col40, #T_068d4_row4_col48, #T_068d4_row5_col0, #T_068d4_row5_col1, #T_068d4_row5_col2, #T_068d4_row5_col3, #T_068d4_row5_col4, #T_068d4_row5_col5, #T_068d4_row5_col6, #T_068d4_row5_col7, #T_068d4_row5_col8, #T_068d4_row5_col9 {
#   background-color: #f2f8fd;
#   color: #000000;
# }
# #T_068d4_row1_col10 {
#   background-color: #c3daee;
#   color: #000000;
# }
# #T_068d4_row1_col11 {
#   background-color: #dbe9f6;
#   color: #000000;
# }
# #T_068d4_row1_col13, #T_068d4_row1_col14, #T_068d4_row1_col15, #T_068d4_row1_col16, #T_068d4_row3_col13, #T_068d4_row3_col14, #T_068d4_row3_col15, #T_068d4_row3_col16, #T_068d4_row3_col21, #T_068d4_row3_col27, #T_068d4_row3_col41, #T_068d4_row3_col47, #T_068d4_row4_col13, #T_068d4_row4_col14, #T_068d4_row4_col15, #T_068d4_row4_col16, #T_068d4_row4_col21, #T_068d4_row4_col27, #T_068d4_row4_col41, #T_068d4_row4_col47, #T_068d4_row5_col15, #T_068d4_row5_col41, #T_068d4_row5_col47, #T_068d4_row6_col21, #T_068d4_row6_col27 {
#   background-color: #f5fafe;
#   color: #000000;
# }
# #T_068d4_row1_col17 {
#   background-color: #dae8f6;
#   color: #000000;
# }
# #T_068d4_row1_col18, #T_068d4_row5_col10, #T_068d4_row5_col18 {
#   background-color: #c1d9ed;
#   color: #000000;
# }
# #T_068d4_row1_col19, #T_068d4_row2_col16, #T_068d4_row4_col12, #T_068d4_row4_col19, #T_068d4_row5_col40, #T_068d4_row5_col48, #T_068d4_row6_col14, #T_068d4_row6_col16 {
#   background-color: #f3f8fe;
#   color: #000000;
# }
# #T_068d4_row1_col21, #T_068d4_row1_col27, #T_068d4_row1_col41, #T_068d4_row1_col47, #T_068d4_row2_col13, #T_068d4_row2_col14, #T_068d4_row2_col15, #T_068d4_row2_col21, #T_068d4_row2_col27, #T_068d4_row2_col41, #T_068d4_row2_col47, #T_068d4_row5_col13, #T_068d4_row5_col14, #T_068d4_row5_col16, #T_068d4_row6_col15, #T_068d4_row6_col41, #T_068d4_row6_col47 {
#   background-color: #f5f9fe;
#   color: #000000;
# }
# #T_068d4_row2_col10 {
#   background-color: #6fb0d7;
#   color: #f1f1f1;
# }
# #T_068d4_row2_col11 {
#   background-color: #a8cee4;
#   color: #000000;
# }
# #T_068d4_row2_col17 {
#   background-color: #a6cee4;
#   color: #000000;
# }
# #T_068d4_row2_col18 {
#   background-color: #6dafd7;
#   color: #f1f1f1;
# }
# #T_068d4_row2_col28, #T_068d4_row3_col12, #T_
# <style type="text/css">
# #T_068d4_row0_col0, #T_068d4_row0_col1, #T_068d4_row0_col2, #T_068d4_row0_col3, #T_068d4_row0_col5, #T_068d4_row0_col6, #T_068d4_row0_col7, #T_068d4_row0_col8, #T_068d4_row0_col9 {
#   background-color: #e9f2fa;
#   color: #000000;
# }
# #T_068d4_row0_col4 {
#   background-color: #eaf2fb;
#   color: #000000;
# }
# #T_068d4_row0_col10, #T_068d4_row0_col18 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_068d4_row0_col11, #T_068d4_row0_col17 {
#   background-color: #8abfdd;
#   color: #000000;
# }
# #T_068d4_row0_col12, #T_068d4_row0_col19 {
#   background-color: #e0ecf8;
#   color: #000000;
# }
# #T_068d4_row0_col13, #T_068d4_row1_col20, #T_068d4_row1_col28, #T_068d4_row2_col20, #T_068d4_row2_col48, #T_068d4_row6_col48 {
#   background-color: #f1f7fd;
#   color: #000000;
# }
# #T_068d4_row0_col14, #T_068d4_row0_col15, #T_068d4_row1_col40, #T_068d4_row1_col48, #T_068d4_row2_col0, #T_068d4_row2_col1, #T_068d4_row2_col2, #T_068d4_row2_col3, #T_068d4_row2_col4, #T_068d4_row2_col5, #T_068d4_row2_col6, #T_068d4_row2_col7, #T_068d4_row2_col8, #T_068d4_row2_col9, #T_068d4_row2_col12, #T_068d4_row2_col19, #T_068d4_row2_col40, #T_068d4_row4_col20, #T_068d4_row4_col28, #T_068d4_row5_col12, #T_068d4_row5_col19, #T_068d4_row6_col20, #T_068d4_row6_col28, #T_068d4_row6_col40 {
#   background-color: #f2f7fd;
#   color: #000000;
# }
# #T_068d4_row0_col16 {
#   background-color: #edf4fc;
#   color: #000000;
# }
# #T_068d4_row0_col20, #T_068d4_row0_col28 {
#   background-color: #eef5fc;
#   color: #000000;
# }
# #T_068d4_row0_col21, #T_068d4_row0_col27, #T_068d4_row1_col12, #T_068d4_row3_col0, #T_068d4_row3_col1, #T_068d4_row3_col2, #T_068d4_row3_col3, #T_068d4_row3_col4, #T_068d4_row3_col5, #T_068d4_row3_col6, #T_068d4_row3_col7, #T_068d4_row3_col8, #T_068d4_row3_col9, #T_068d4_row5_col20, #T_068d4_row5_col28, #T_068d4_row6_col13 {
#   background-color: #f4f9fe;
#   color: #000000;
# }
# #T_068d4_row0_col22, #T_068d4_row0_col29, #T_068d4_row0_col42, #T_068d4_row0_col49, #T_068d4_row1_col29, #T_068d4_row2_col22, #T_068d4_row2_col29, #T_068d4_row3_col29, #T_068d4_row4_col0, #T_068d4_row4_col1, #T_068d4_row4_col2, #T_068d4_row4_col3, #T_068d4_row4_col4, #T_068d4_row4_col5, #T_068d4_row4_col6, #T_068d4_row4_col7, #T_068d4_row4_col8, #T_068d4_row4_col9, #T_068d4_row5_col21, #T_068d4_row5_col27, #T_068d4_row6_col22, #T_068d4_row6_col29 {
#   background-color: #f6faff;
#   color: #000000;
# }
# #T_068d4_row0_col23, #T_068d4_row0_col24, #T_068d4_row0_col25, #T_068d4_row0_col26, #T_068d4_row0_col30, #T_068d4_row0_col31, #T_068d4_row0_col32, #T_068d4_row0_col33, #T_068d4_row0_col34, #T_068d4_row0_col35, #T_068d4_row0_col36, #T_068d4_row0_col37, #T_068d4_row0_col38, #T_068d4_row0_col39, #T_068d4_row0_col43, #T_068d4_row0_col44, #T_068d4_row0_col45, #T_068d4_row0_col46, #T_068d4_row1_col0, #T_068d4_row1_col1, #T_068d4_row1_col2, #T_068d4_row1_col3, #T_068d4_row1_col4, #T_068d4_row1_col5, #T_068d4_row1_col6, #T_068d4_row1_col7, #T_068d4_row1_col8, #T_068d4_row1_col9, #T_068d4_row1_col22, #T_068d4_row1_col23, #T_068d4_row1_col24, #T_068d4_row1_col25, #T_068d4_row1_col26, #T_068d4_row1_col30, #T_068d4_row1_col31, #T_068d4_row1_col32, #T_068d4_row1_col33, #T_068d4_row1_col34, #T_068d4_row1_col35, #T_068d4_row1_col36, #T_068d4_row1_col37, #T_068d4_row1_col38, #T_068d4_row1_col39, #T_068d4_row1_col42, #T_068d4_row1_col43, #T_068d4_row1_col44, #T_068d4_row1_col45, #T_068d4_row1_col46, #T_068d4_row1_col49, #T_068d4_row2_col23, #T_068d4_row2_col24, #T_068d4_row2_col25, #T_068d4_row2_col26, #T_068d4_row2_col30, #T_068d4_row2_col31, #T_068d4_row2_col32, #T_068d4_row2_col33, #T_068d4_row2_col34, #T_068d4_row2_col35, #T_068d4_row2_col36, #T_068d4_row2_col37, #T_068d4_row2_col38, #T_068d4_row2_col39, #T_068d4_row2_col42, #T_068d4_row2_col43, #T_068d4_row2_col44, #T_068d4_row2_col45, #T_068d4_row2_col46, #T_068d4_row2_col49, #T_068d4_row3_col22, #T_068d4_row3_col23, #T_068d4_row3_col24, #T_068d4_row3_col25, #T_068d4_row3_col26, #T_068d4_row3_col30, #T_068d4_row3_col31, #T_068d4_row3_col32, #T_068d4_row3_col33, #T_068d4_row3_col34, #T_068d4_row3_col35, #T_068d4_row3_col36, #T_068d4_row3_col37, #T_068d4_row3_col38, #T_068d4_row3_col39, #T_068d4_row3_col42, #T_068d4_row3_col43, #T_068d4_row3_col44, #T_068d4_row3_col45, #T_068d4_row3_col46, #T_068d4_row3_col49, #T_068d4_row4_col22, #T_068d4_row4_col23, #T_068d4_row4_col24, #T_068d4_row4_col25, #T_068d4_row4_col26, #T_068d4_row4_col29, #T_068d4_row4_col30, #T_068d4_row4_col31, #T_068d4_row4_col32, #T_068d4_row4_col33, #T_068d4_row4_col34, #T_068d4_row4_col35, #T_068d4_row4_col36, #T_068d4_row4_col37, #T_068d4_row4_col38, #T_068d4_row4_col39, #T_068d4_row4_col42, #T_068d4_row4_col43, #T_068d4_row4_col44, #T_068d4_row4_col45, #T_068d4_row4_col46, #T_068d4_row4_col49, #T_068d4_row5_col22, #T_068d4_row5_col23, #T_068d4_row5_col24, #T_068d4_row5_col25, #T_068d4_row5_col26, #T_068d4_row5_col29, #T_068d4_row5_col30, #T_068d4_row5_col31, #T_068d4_row5_col32, #T_068d4_row5_col33, #T_068d4_row5_col34, #T_068d4_row5_col35, #T_068d4_row5_col36, #T_068d4_row5_col37, #T_068d4_row5_col38, #T_068d4_row5_col39, #T_068d4_row5_col42, #T_068d4_row5_col43, #T_068d4_row5_col44, #T_068d4_row5_col45, #T_068d4_row5_col46, #T_068d4_row5_col49, #T_068d4_row6_col23, #T_068d4_row6_col24, #T_068d4_row6_col25, #T_068d4_row6_col26, #T_068d4_row6_col30, #T_068d4_row6_col31, #T_068d4_row6_col32, #T_068d4_row6_col33, #T_068d4_row6_col34, #T_068d4_row6_col35, #T_068d4_row6_col36, #T_068d4_row6_col37, #T_068d4_row6_col38, #T_068d4_row6_col39, #T_068d4_row6_col42, #T_068d4_row6_col43, #T_068d4_row6_col44, #T_068d4_row6_col45, #T_068d4_row6_col46, #T_068d4_row6_col49 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_068d4_row0_col40, #T_068d4_row0_col48 {
#   background-color: #ecf4fb;
#   color: #000000;
# }
# #T_068d4_row0_col41, #T_068d4_row0_col47, #T_068d4_row3_col20, #T_068d4_row3_col28, #T_068d4_row3_col40, #T_068d4_row3_col48, #T_068d4_row4_col40, #T_068d4_row4_col48, #T_068d4_row5_col0, #T_068d4_row5_col1, #T_068d4_row5_col2, #T_068d4_row5_col3, #T_068d4_row5_col4, #T_068d4_row5_col5, #T_068d4_row5_col6, #T_068d4_row5_col7, #T_068d4_row5_col8, #T_068d4_row5_col9 {
#   background-color: #f2f8fd;
#   color: #000000;
# }
# #T_068d4_row1_col10 {
#   background-color: #c3daee;
#   color: #000000;
# }
# #T_068d4_row1_col11 {
#   background-color: #dbe9f6;
#   color: #000000;
# }
# #T_068d4_row1_col13, #T_068d4_row1_col14, #T_068d4_row1_col15, #T_068d4_row1_col16, #T_068d4_row3_col13, #T_068d4_row3_col14, #T_068d4_row3_col15, #T_068d4_row3_col16, #T_068d4_row3_col21, #T_068d4_row3_col27, #T_068d4_row3_col41, #T_068d4_row3_col47, #T_068d4_row4_col13, #T_068d4_row4_col14, #T_068d4_row4_col15, #T_068d4_row4_col16, #T_068d4_row4_col21, #T_068d4_row4_col27, #T_068d4_row4_col41, #T_068d4_row4_col47, #T_068d4_row5_col15, #T_068d4_row5_col41, #T_068d4_row5_col47, #T_068d4_row6_col21, #T_068d4_row6_col27 {
#   background-color: #f5fafe;
#   color: #000000;
# }
# #T_068d4_row1_col17 {
#   background-color: #dae8f6;
#   color: #000000;
# }
# #T_068d4_row1_col18, #T_068d4_row5_col10, #T_068d4_row5_col18 {
#   background-color: #c1d9ed;
#   color: #000000;
# }
# #T_068d4_row1_col19, #T_068d4_row2_col16, #T_068d4_row4_col12, #T_068d4_row4_col19, #T_068d4_row5_col40, #T_068d4_row5_col48, #T_068d4_row6_col14, #T_068d4_row6_col16 {
#   background-color: #f3f8fe;
#   color: #000000;
# }
# #T_068d4_row1_col21, #T_068d4_row1_col27, #T_068d4_row1_col41, #T_068d4_row1_col47, #T_068d4_row2_col13, #T_068d4_row2_col14, #T_068d4_row2_col15, #T_068d4_row2_col21, #T_068d4_row2_col27, #T_068d4_row2_col41, #T_068d4_row2_col47, #T_068d4_row5_col13, #T_068d4_row5_col14, #T_068d4_row5_col16, #T_068d4_row6_col15, #T_068d4_row6_col41, #T_068d4_row6_col47 {
#   background-color: #f5f9fe;
#   color: #000000;
# }
# #T_068d4_row2_col10 {
#   background-color: #6fb0d7;
#   color: #f1f1f1;
# }
# #T_068d4_row2_col11 {
#   background-color: #a8cee4;
#   color: #000000;
# }
# #T_068d4_row2_col17 {
#   background-color: #a6cee4;
#   color: #000000;
# }
# #T_068d4_row2_col18 {
#   background-color: #6dafd7;
#   color: #f1f1f1;
# }
# #T_068d4_row2_col28, #T_068d4_row3_col12, #T_

# %%
hdb_top_vars = top_variable(df_hdb_labeled, hdb_labels)
hdb_top_vars
# Out:
# {-1: ['totmou',
#   'adjmou',
#   'totcalls',
#   'adjqty',
#   'totrev',
#   'adjrev',
#   'avg3mou',
#   'mou_Mean',
#   'avg6mou',
#   'avgmou'],
#  0: ['totmou',
#   'adjmou',
#   'totcalls',
#   'adjqty',
#   'totrev',
#   'adjrev',
#   'avg3mou',
#   'mou_Mean',
#   'avg6mou',
#   'avgmou'],
#  1: ['totmou',
#   'adjmou',
#   'totcalls',
#   'adjqty',
#   'totrev',
#   'adjrev',
#   'avg3mou',
#   'mou_Mean',
#   'avg6mou',
#   'avgmou'],
#  2: ['totmou',
#   'adjmou',
#   'totcalls',
#   'adjqty',
#   'totrev',
#   'adjrev',
#   'avg3mou',
#   'mou_Mean',
#   'avg6mou',
#   'avgmou'],
#  3: ['totmou',
#   'adjmou',
#   'totcalls',
#   'adjqty',
#   'totrev',
#   'adjrev',
#   'mou_Mean',
#   'avg3mou',
#   'avg6mou',
#   'avgmou'],
#  4: ['totmou',
#   'adjmou',
#   'totcalls',
#   'adjqty',
#   'totrev',
#   'adjrev',
#   'avg3mou',
#   'mou_Mean',
#   'avg6mou',
#   'avgmou'],
#  5: ['totmou',
#   'adjmou',
#   'totcalls',
#   'adjqty',
#   'totrev',
#   'adjrev',
#   'avg3mou',
#   'mou_Mean',
#   'avg6mou',
#   'avgmou']}

# %%
plot_pca(X, hdb_labels)

# %%
top_feats_hdb = list(set(sum(hdb_top_vars.values(), [])))

# %%
plot_cluster_heatmap(df_hdb_labeled, hdb_labels, top_feats_hdb)

# %%
plot_feature_boxplots(df_hdb_labeled, hdb_labels, top_feats_hdb[:5])
# Out:
# C:\Users\Eden Thomas\AppData\Local\Temp\ipykernel_27704\3435183386.py:7: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x="cluster", y=feature, data=df, palette="tab10")
# C:\Users\Eden Thomas\AppData\Local\Temp\ipykernel_27704\3435183386.py:7: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x="cluster", y=feature, data=df, palette="tab10")
# C:\Users\Eden Thomas\AppData\Local\Temp\ipykernel_27704\3435183386.py:7: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x="cluster", y=feature, data=df, palette="tab10")
# C:\Users\Eden Thomas\AppData\Local\Temp\ipykernel_27704\3435183386.py:7: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x="cluster", y=feature, data=df, palette="tab10")
# C:\Users\Eden Thomas\AppData\Local\Temp\ipykernel_27704\3435183386.py:7: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x="cluster", y=feature, data=df, palette="tab10")

# %%
plot_parallel_coordinates(df_hdb_labeled, hdb_labels, top_feats_hdb)
